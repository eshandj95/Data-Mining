# %% [markdown]
# # PA 3: Association Analysis - Apriori Algorithm

# %% [markdown]
# ## Student Details
#
# Student Name and ID:

# %% [markdown]
# ## Submission Instructions
#
#
# Step 1: Create a folder and name it 'yourNetID_PA3'
#
# Step 2: Rename this submission file as 'yourNetID_PA3.ipynb' and place it inside the folder 'yourNetID_PA3'
#
# Step 3: Rename the updated dataset file 'dataset.csv' and place it inside the folder 'yourNetID_PA3'
#
# Step 4: Your submission folder should include ONLY the following files:
#     * apriory.py,
#     * yourNetID_PA3.ipynb,
#     * dataset.csv,
#     * toyDS.csv
#
# Step 5: Zip this folder and submit it on BB. Your final submission folder name should be 'yourNetID_PA3.ZIP'

# %% [markdown]
# ## Programming Assignment Details
#
# Before you start:
# - Note that this is an individual assignment.
# - Be familiar with the algorithm and with the dataset.
# - If you use external sources make sure that you cite them, and be specific!
# - Make sure that your code is running before you upload your submission file. TA will not debug your code.
# - Start early!
#
#
# For this assignment, you will have to use:
# * Jupyter notebook,
# * the 'Random Shopping cart' dataset [01],
# * and the Apriori Algorithm (apriory.py)[02]. Note that the apriory.py file is modified to run with Python 3.

# %% [markdown]
# ## - - - - - - - - - - - - - - - - - - - - - - - SOLUTION - - - - - - - - - - - - - - - - - - - - - - -

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Import your Libraries
import pandas as pd
import csv

# %% [markdown]
# ### Task 1: DataSet Preprocess
# Before you start you need to modify your dataset 'dataset_group.csv' to look like the toyDS.csv.  Each transaction is at one line with a variable length.  Discard the date attribute (1st attribute) from your dataset.  For example, in your dataset transaction#4 should look like:
#
#     cereals,juice,lunch meat,soda,toilet paper,all-purpose
#
# Export your modified dataset in a file named 'dataset.csv'.
#
# Use pandas to Read and Print the first 7 transactions of the 'dataset.csv'.

# %%
from IPython.display import Image
print ('ScreenShot of the toyDS.csv')
Image("SampleScreen01.png")
# Out:
# ScreenShot of the toyDS.csv

# %%
# # # # # # # # #  Code for Task 1 # # # # # # # # #
wal = pd.read_csv('dataset_group.csv')
wal.rename(columns={'2000-01-01':'Date', '1':'ID','yogurt':'Items'}, inplace=True)
wal.drop('Date', axis=1, inplace=True)
d=wal.groupby('ID').agg(lambda x: x.tolist())
with open('dataset.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',', quotechar="'", quoting=csv.QUOTE_MINIMAL)
    for index, row in d.iterrows():
        writer.writerow(row[0])
csvfile.close()
#names = list(range(0,31))
wal1 = pd.read_csv('dataset.csv', names=list(range(0,30)),header=None)
wal1.head(7)
#wal = pd.read_csv('dataset.csv', sep='delimiter', header=None)
# Out:
#                   0              1           2             3             4   \
# 0               pork  sandwich bags  lunch meat  all- purpose         flour
# 1       toilet paper        shampoo   hand soap       waffles    vegetables
# 2               soda           pork        soap     ice cream  toilet paper
# 3            cereals          juice  lunch meat          soda  toilet paper
# 4    sandwich loaves          pasta   tortillas         mixes     hand soap
# 5  laundry detergent   toilet paper        eggs  toilet paper    vegetables
# 6   individual meals   paper towels   tortillas    vegetables          milk
#
#              5                             6                             7   \
# 0          soda                        butter                    vegetables
# 1       cheeses                         mixes                          milk
# 2  dinner rolls                     hand soap               spaghetti sauce
# 3  all- purpose                           NaN                           NaN
# 4  toilet paper                    vegetables                    vegetables
# 5        bagels  dishwashing liquid/detergent                       cereals
# 6     ice cream                         juice  dishwashing liquid/detergent
#
#               8                  9      ...                 20  \
# 0           beef      aluminum foil     ...                NaN
# 1  sandwich bags  laundry detergent     ...      aluminum foil
# 2           milk            ketchup     ...          ice cream
# 3            NaN                NaN     ...                NaN
# 4   paper towels         vegetables     ...            waffles
# 5   paper towels  laundry detergent     ...            poultry
# 6           soap      sandwich bags     ...               eggs
#
#                  21             22            23               24       25  \
# 0               NaN            NaN           NaN              NaN      NaN
# 1         tortillas          mixes           NaN              NaN      NaN
# 2           shampoo     lunch meat       cereals  spaghetti sauce     pork
# 3               NaN            NaN           NaN              NaN      NaN
# 4  individual meals     vegetables  dinner rolls     all- purpose     soda
# 5            bagels  aluminum foil        butter  spaghetti sauce  ketchup
# 6   spaghetti sauce         fruits  toilet paper              NaN      NaN
#
#              26       27    28          29
# 0           NaN      NaN   NaN         NaN
# 1           NaN      NaN   NaN         NaN
# 2    vegetables  cheeses  eggs  vegetables
# 3           NaN      NaN   NaN         NaN
# 4        yogurt      NaN   NaN         NaN
# 5  all- purpose     milk   NaN         NaN
# 6           NaN      NaN   NaN         NaN
#
# [7 rows x 30 columns]

# %% [markdown]
# ### Task 2: Run apriory.py and Evaluate Results
#
# In this task, you have to find how you will be able to execute and print apriory results by making use only the apriory.py. In other words "DO NOT USE ANY OTHER LIBRARY FOR TASK 2!!!".
#
# (*) For those that are not familiar with python and coding this could be a quite demanding task.
#
#
# You will have to execute apriori algorithm "3" times for different combinations of support and confidence.
# Print the results of apriory for 'dataset.csv' by making use ONLY the provided methods.
#
# Do not forget to add your reasoning (explain the result outcome) at the top of each case in a nice and readable way.
#
# You are allowed to use the python print method to print your results. DO NOT add your reasoning as comments.

# %%
print ('# # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #') 
print(' There is no definite rule to fix a value. It is adviced to keep a fair balance of support and confidence value to get appropriate/new rules. Suppose you set a very high value, in that case you might get very less/ no rules and you might miss a few rules that you have wanted to see. For a low value, you might get many values and too much of information is not helpful always.\n')
print ('Case 1 (minimum support=0.125 and minimum confidence=0.55)')
print ('Case 1 Reasoning:We have selected support as 0.125 to obtain most of the possible values.')
print ('Case 1 Output:')
# %run apriori.py -f dataset.csv -s 0.125 -c 0.55
# Out:
# # # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #
#  There is no definite rule to fix a value. It is adviced to keep a fair balance of support and confidence value to get appropriate/new rules. Suppose you set a very high value, in that case you might get very less/ no rules and you might miss a few rules that you have wanted to see. For a low value, you might get many values and too much of information is not helpful always.
#
# Case 1 (minimum support=0.125 and minimum confidence=0.55)
# Case 1 Reasoning:We have selected support as 0.125 to obtain most of the possible values.
# Case 1 Output:
#
# ------------ITEMS-----------------
# item: ('sugar', 'vegetables', 'aluminum foil') , 0.126
# item: ('soda', 'toilet paper', 'vegetables') , 0.126
# item: ('flour', 'vegetables', 'mixes') , 0.126
# item: ('vegetables', 'spaghetti sauce', 'fruits') , 0.126
# item: ('paper towels', 'vegetables', 'sandwich bags') , 0.126
# item: ('paper towels', 'vegetables', 'beef') , 0.126
# item: ('pasta', 'vegetables', 'all- purpose') , 0.126
# item: ('soda', 'cereals', 'vegetables') , 0.126
# item: ('yogurt', 'vegetables', 'soap') , 0.126
# item: ('tortillas', 'vegetables', 'dishwashing liquid/detergent') , 0.126
# item: ('soda', 'coffee/tea', 'vegetables') , 0.126
# item: ('milk', 'vegetables', 'sandwich bags') , 0.126
# item: ('vegetables', 'individual meals', 'dishwashing liquid/detergent') , 0.126
# item: ('toilet paper', 'vegetables', 'mixes') , 0.126
# item: ('butter', 'vegetables', 'mixes') , 0.126
# item: ('bagels', 'vegetables', 'beef') , 0.126
# item: ('sugar', 'vegetables', 'bagels') , 0.126
# item: ('sandwich loaves', 'vegetables', 'mixes') , 0.126
# item: ('butter', 'vegetables', 'juice') , 0.126
# item: ('cereals', 'vegetables', 'tortillas') , 0.126
# item: ('tortillas', 'vegetables', 'bagels') , 0.126
# item: ('milk', 'vegetables', 'juice') , 0.126
# item: ('yogurt', 'vegetables', 'pork') , 0.126
# item: ('coffee/tea', 'vegetables', 'soap') , 0.126
# item: ('vegetables', 'beef', 'juice') , 0.126
# item: ('dinner rolls', 'hand soap', 'vegetables') , 0.126
# item: ('coffee/tea', 'ice cream', 'vegetables') , 0.126
# item: ('toilet paper', 'vegetables', 'dishwashing liquid/detergent') , 0.126
# item: ('cereals', 'vegetables', 'individual meals') , 0.126
# item: ('ketchup', 'vegetables', 'dishwashing liquid/detergent') , 0.126
# item: ('dinner rolls', 'vegetables', 'all- purpose') , 0.126
# item: ('coffee/tea', 'sandwich loaves', 'vegetables') , 0.126
# item: ('dinner rolls', 'coffee/tea', 'vegetables') , 0.126
# item: ('vegetables', 'paper towels', 'bagels') , 0.126
# item: ('vegetables', 'paper towels', 'cheeses') , 0.126
# item: ('vegetables', 'sandwich bags', 'dishwashing liquid/detergent') , 0.126
# item: ('laundry detergent', 'vegetables', 'fruits') , 0.126
# item: ('paper towels', 'vegetables', 'mixes') , 0.126
# item: ('vegetables', 'lunch meat', 'all- purpose') , 0.126
# item: ('aluminum foil', 'vegetables', 'soap') , 0.126
# item: ('soda', 'vegetables', 'beef') , 0.126
# item: ('shampoo', 'vegetables', 'mixes') , 0.126
# item: ('vegetables', 'sandwich bags', 'mixes') , 0.126
# item: ('ketchup', 'vegetables', 'ice cream') , 0.126
# item: ('aluminum foil', 'vegetables', 'individual meals') , 0.126
# item: ('flour', 'vegetables', 'lunch meat') , 0.127
# item: ('vegetables', 'individual meals', 'spaghetti sauce') , 0.127
# item: ('coffee/tea', 'paper towels', 'vegetables') , 0.127
# item: ('bagels', 'vegetables', 'sandwich bags') , 0.127
# item: ('ketchup', 'vegetables', 'beef') , 0.127
# item: ('butter', 'vegetables', 'sandwich bags') , 0.127
# item: ('vegetables', 'laundry detergent', 'paper towels') , 0.127
# item: ('waffles', 'vegetables', 'mixes') , 0.127
# item: ('milk', 'vegetables', 'spaghetti sauce') , 0.127
# item: ('shampoo', 'vegetables', 'waffles') , 0.127
# item: ('ketchup', 'milk', 'vegetables') , 0.127
# item: ('aluminum foil', 'vegetables', 'sandwich bags') , 0.127
# item: ('cereals', 'vegetables', 'sandwich bags') , 0.127
# item: ('dinner rolls', 'tortillas', 'vegetables') , 0.127
# item: ('flour', 'vegetables', 'cheeses') , 0.127
# item: ('sugar', 'vegetables', 'cheeses') , 0.127
# item: ('sugar', 'vegetables', 'soap') , 0.127
# item: ('milk', 'vegetables', 'soap') , 0.127
# item: ('soda', 'vegetables', 'ketchup') , 0.127
# item: ('paper towels', 'vegetables', 'shampoo') , 0.127
# item: ('ketchup', 'vegetables', 'bagels') , 0.127
# item: ('butter', 'beef') , 0.128
# item: ('fruits', 'pork') , 0.128
# item: ('sandwich loaves', 'vegetables', 'cheeses') , 0.128
# item: ('dinner rolls', 'vegetables', 'sandwich bags') , 0.128
# item: ('ice cream', 'vegetables', 'spaghetti sauce') , 0.128
# item: ('vegetables', 'beef', 'spaghetti sauce') , 0.128
# item: ('dinner rolls', 'milk', 'vegetables') , 0.128
# item: ('milk', 'vegetables', 'beef') , 0.128
# item: ('vegetables', 'mixes', 'spaghetti sauce') , 0.128
# item: ('vegetables', 'sandwich bags', 'eggs') , 0.128
# item: ('soda', 'shampoo', 'vegetables') , 0.128
# item: ('pasta', 'vegetables', 'dishwashing liquid/detergent') , 0.128
# item: ('vegetables', 'ice cream', 'all- purpose') , 0.128
# item: ('laundry detergent', 'vegetables', 'bagels') , 0.128
# item: ('milk', 'vegetables', 'mixes') , 0.128
# item: ('cereals', 'vegetables', 'fruits') , 0.128
# item: ('vegetables', 'juice', 'soap') , 0.128
# item: ('aluminum foil', 'sandwich loaves', 'vegetables') , 0.128
# item: ('vegetables', 'eggs', 'pork') , 0.128
# item: ('all- purpose', 'vegetables', 'dishwashing liquid/detergent') , 0.128
# item: ('vegetables', 'poultry', 'pork') , 0.128
# item: ('vegetables', 'juice', 'dishwashing liquid/detergent') , 0.128
# item: ('shampoo', 'vegetables', 'eggs') , 0.128
# item: ('ice cream', 'vegetables', 'bagels') , 0.128
# item: ('paper towels', 'vegetables', 'spaghetti sauce') , 0.128
# item: ('dinner rolls', 'vegetables', 'soap') , 0.128
# item: ('toilet paper', 'vegetables', 'lunch meat') , 0.128
# item: ('dinner rolls', 'vegetables', 'ketchup') , 0.128
# item: ('sugar', 'toilet paper', 'vegetables') , 0.128
# item: ('sandwich loaves', 'laundry detergent') , 0.129
# item: ('dinner rolls', 'sandwich loaves', 'vegetables') , 0.129
# item: ('aluminum foil', 'flour', 'vegetables') , 0.129
# item: ('flour', 'vegetables', 'poultry') , 0.129
# item: ('ketchup', 'sandwich loaves', 'vegetables') , 0.129
# item: ('vegetables', 'beef', 'dishwashing liquid/detergent') , 0.129
# item: ('dinner rolls', 'toilet paper', 'vegetables') , 0.129
# item: ('soda', 'vegetables', 'sandwich bags') , 0.129
# item: ('soda', 'vegetables', 'bagels') , 0.129
# item: ('dinner rolls', 'flour', 'vegetables') , 0.129
# item: ('vegetables', 'ice cream', 'individual meals') , 0.129
# item: ('vegetables', 'sandwich bags', 'lunch meat') , 0.129
# item: ('paper towels', 'vegetables', 'waffles') , 0.129
# item: ('ice cream', 'vegetables', 'sandwich bags') , 0.129
# item: ('pasta', 'vegetables', 'soap') , 0.129
# item: ('sandwich loaves', 'vegetables', 'shampoo') , 0.129
# item: ('ketchup', 'toilet paper', 'vegetables') , 0.129
# item: ('hand soap', 'pork') , 0.130
# item: ('soap', 'vegetables', 'all- purpose') , 0.130
# item: ('vegetables', 'sandwich bags', 'soap') , 0.130
# item: ('soda', 'flour', 'vegetables') , 0.130
# item: ('aluminum foil', 'vegetables', 'spaghetti sauce') , 0.130
# item: ('pasta', 'vegetables', 'waffles') , 0.130
# item: ('vegetables', 'beef', 'cheeses') , 0.130
# item: ('pasta', 'laundry detergent', 'vegetables') , 0.130
# item: ('laundry detergent', 'vegetables', 'lunch meat') , 0.130
# item: ('coffee/tea', 'vegetables', 'juice') , 0.130
# item: ('aluminum foil', 'vegetables', 'ketchup') , 0.130
# item: ('soap', 'vegetables', 'dishwashing liquid/detergent') , 0.130
# item: ('aluminum foil', 'vegetables', 'fruits') , 0.130
# item: ('milk', 'vegetables', 'bagels') , 0.130
# item: ('yogurt', 'ice cream', 'vegetables') , 0.130
# item: ('toilet paper', 'milk', 'vegetables') , 0.130
# item: ('vegetables', 'individual meals', 'waffles') , 0.130
# item: ('dinner rolls', 'ice cream', 'vegetables') , 0.131
# item: ('vegetables', 'beef', 'waffles') , 0.131
# item: ('vegetables', 'beef', 'soap') , 0.131
# item: ('paper towels', 'milk', 'vegetables') , 0.131
# item: ('aluminum foil', 'coffee/tea', 'vegetables') , 0.131
# item: ('vegetables', 'individual meals', 'soap') , 0.131
# item: ('yogurt', 'vegetables', 'ketchup') , 0.131
# item: ('yogurt', 'tortillas', 'vegetables') , 0.131
# item: ('vegetables', 'paper towels', 'soap') , 0.131
# item: ('cereals', 'vegetables', 'bagels') , 0.131
# item: ('vegetables', 'bagels', 'cheeses') , 0.131
# item: ('aluminum foil', 'vegetables', 'all- purpose') , 0.131
# item: ('yogurt', 'toilet paper', 'vegetables') , 0.131
# item: ('vegetables', 'waffles', 'fruits') , 0.131
# item: ('laundry detergent', 'vegetables', 'soap') , 0.131
# item: ('laundry detergent', 'vegetables', 'individual meals') , 0.131
# item: ('toilet paper', 'vegetables', 'soap') , 0.131
# item: ('sugar', 'vegetables', 'beef') , 0.131
# item: ('yogurt', 'shampoo', 'vegetables') , 0.131
# item: ('cereals', 'vegetables', 'soap') , 0.131
# item: ('toilet paper', 'laundry detergent', 'vegetables') , 0.131
# item: ('butter', 'hand soap') , 0.132
# item: ('sandwich loaves', 'dishwashing liquid/detergent') , 0.132
# item: ('hand soap', 'bagels') , 0.132
# item: ('sugar', 'pork') , 0.132
# item: ('sugar', 'sandwich bags') , 0.132
# item: ('sandwich loaves', 'pork') , 0.132
# item: ('sugar', 'cereals', 'vegetables') , 0.132
# item: ('vegetables', 'bagels', 'mixes') , 0.132
# item: ('ice cream', 'vegetables', 'juice') , 0.132
# item: ('yogurt', 'flour', 'vegetables') , 0.132
# item: ('paper towels', 'toilet paper', 'vegetables') , 0.132
# item: ('tortillas', 'vegetables', 'lunch meat') , 0.132
# item: ('aluminum foil', 'milk', 'vegetables') , 0.132
# item: ('vegetables', 'beef', 'lunch meat') , 0.132
# item: ('vegetables', 'poultry', 'fruits') , 0.132
# item: ('cereals', 'ice cream', 'vegetables') , 0.132
# item: ('vegetables', 'milk', 'ice cream') , 0.132
# item: ('milk', 'vegetables', 'lunch meat') , 0.132
# item: ('toilet paper', 'vegetables', 'cheeses') , 0.132
# item: ('paper towels', 'pasta', 'vegetables') , 0.132
# item: ('yogurt', 'vegetables', 'fruits') , 0.132
# item: ('dinner rolls', 'paper towels', 'vegetables') , 0.132
# item: ('aluminum foil', 'toilet paper', 'vegetables') , 0.132
# item: ('dinner rolls', 'vegetables', 'bagels') , 0.132
# item: ('sugar', 'vegetables', 'eggs') , 0.132
# item: ('paper towels', 'vegetables', 'dishwashing liquid/detergent') , 0.132
# item: ('vegetables', 'individual meals', 'cheeses') , 0.132
# item: ('hand soap', 'flour') , 0.133
# item: ('flour', 'spaghetti sauce') , 0.133
# item: ('shampoo', 'vegetables', 'cheeses') , 0.133
# item: ('soda', 'vegetables', 'individual meals') , 0.133
# item: ('vegetables', 'dishwashing liquid/detergent', 'cheeses') , 0.133
# item: ('dinner rolls', 'vegetables', 'juice') , 0.133
# item: ('vegetables', 'bagels', 'waffles') , 0.133
# item: ('yogurt', 'coffee/tea', 'vegetables') , 0.133
# item: ('tortillas', 'vegetables', 'eggs') , 0.133
# item: ('vegetables', 'paper towels', 'all- purpose') , 0.133
# item: ('vegetables', 'bagels', 'lunch meat') , 0.133
# item: ('ketchup', 'vegetables', 'paper towels') , 0.133
# item: ('ketchup', 'laundry detergent', 'vegetables') , 0.133
# item: ('vegetables', 'beef', 'fruits') , 0.133
# item: ('sugar', 'vegetables', 'ice cream') , 0.133
# item: ('aluminum foil', 'pasta', 'vegetables') , 0.133
# item: ('cereals', 'vegetables', 'shampoo') , 0.133
# item: ('vegetables', 'ice cream', 'fruits') , 0.133
# item: ('vegetables', 'mixes', 'eggs') , 0.133
# item: ('aluminum foil', 'vegetables', 'beef') , 0.133
# item: ('ketchup', 'vegetables', 'poultry') , 0.133
# item: ('ketchup', 'vegetables', 'waffles') , 0.133
# item: ('sandwich loaves', 'vegetables', 'soap') , 0.133
# item: ('shampoo', 'vegetables', 'lunch meat') , 0.133
# item: ('toilet paper', 'vegetables', 'bagels') , 0.133
# item: ('vegetables', 'waffles', 'all- purpose') , 0.133
# item: ('vegetables', 'eggs', 'fruits') , 0.133
# item: ('ice cream', 'vegetables', 'beef') , 0.133
# item: ('cheeses', 'vegetables', 'fruits') , 0.133
# item: ('vegetables', 'lunch meat', 'fruits') , 0.133
# item: ('vegetables', 'sandwich bags', 'waffles') , 0.133
# item: ('pasta', 'pork') , 0.133
# item: ('hand soap', 'paper towels') , 0.133
# item: ('paper towels', 'vegetables', 'juice') , 0.133
# item: ('coffee/tea', 'vegetables', 'ketchup') , 0.133
# item: ('soda', 'ice cream', 'vegetables') , 0.133
# item: ('yogurt', 'vegetables', 'sugar') , 0.133
# item: ('cereals', 'vegetables', 'beef') , 0.133
# item: ('sugar', 'vegetables', 'dishwashing liquid/detergent') , 0.133
# item: ('aluminum foil', 'vegetables', 'paper towels') , 0.133
# item: ('butter', 'laundry detergent', 'vegetables') , 0.133
# item: ('yogurt', 'vegetables', 'individual meals') , 0.133
# item: ('butter', 'vegetables', 'poultry') , 0.133
# item: ('yogurt', 'sandwich loaves', 'vegetables') , 0.133
# item: ('soda', 'vegetables', 'paper towels') , 0.133
# item: ('vegetables', 'bagels', 'juice') , 0.133
# item: ('vegetables', 'ice cream', 'dishwashing liquid/detergent') , 0.133
# item: ('ketchup', 'vegetables', 'juice') , 0.133
# item: ('coffee/tea', 'vegetables', 'cheeses') , 0.133
# item: ('sandwich loaves', 'vegetables', 'individual meals') , 0.133
# item: ('shampoo', 'laundry detergent', 'vegetables') , 0.133
# item: ('aluminum foil', 'cereals', 'vegetables') , 0.133
# item: ('vegetables', 'mixes', 'cheeses') , 0.133
# item: ('pasta', 'ice cream', 'vegetables') , 0.133
# item: ('vegetables', 'soap', 'cheeses') , 0.133
# item: ('sandwich loaves', 'eggs') , 0.134
# item: ('sandwich loaves', 'milk') , 0.134
# item: ('shampoo', 'tortillas') , 0.134
# item: ('dinner rolls', 'vegetables', 'mixes') , 0.134
# item: ('laundry detergent', 'vegetables', 'mixes') , 0.134
# item: ('laundry detergent', 'vegetables', 'spaghetti sauce') , 0.134
# item: ('soda', 'vegetables', 'dishwashing liquid/detergent') , 0.134
# item: ('pasta', 'vegetables', 'cheeses') , 0.134
# item: ('individual meals', 'vegetables', 'bagels') , 0.134
# item: ('vegetables', 'ice cream', 'soap') , 0.134
# item: ('sandwich loaves', 'ice cream', 'vegetables') , 0.134
# item: ('aluminum foil', 'laundry detergent', 'vegetables') , 0.134
# item: ('ketchup', 'vegetables', 'mixes') , 0.134
# item: ('vegetables', 'spaghetti sauce', 'cheeses') , 0.134
# item: ('pasta', 'vegetables', 'poultry') , 0.134
# item: ('aluminum foil', 'vegetables', 'dishwashing liquid/detergent') , 0.134
# item: ('vegetables', 'individual meals', 'eggs') , 0.134
# item: ('cereals', 'vegetables', 'toilet paper') , 0.134
# item: ('yogurt', 'vegetables', 'sandwich bags') , 0.134
# item: ('vegetables', 'lunch meat', 'juice') , 0.134
# item: ('cereals', 'vegetables', 'waffles') , 0.134
# item: ('laundry detergent', 'vegetables', 'waffles') , 0.134
# item: ('hand soap', 'soap') , 0.135
# item: ('flour', 'beef') , 0.135
# item: ('yogurt', 'paper towels', 'vegetables') , 0.135
# item: ('paper towels', 'cereals', 'vegetables') , 0.135
# item: ('vegetables', 'paper towels', 'lunch meat') , 0.135
# item: ('pasta', 'vegetables', 'spaghetti sauce') , 0.135
# item: ('ketchup', 'vegetables', 'cheeses') , 0.135
# item: ('vegetables', 'bagels', 'fruits') , 0.135
# item: ('vegetables', 'beef', 'poultry') , 0.135
# item: ('vegetables', 'lunch meat', 'cheeses') , 0.135
# item: ('ketchup', 'vegetables', 'sandwich bags') , 0.135
# item: ('yogurt', 'pasta', 'vegetables') , 0.135
# item: ('ketchup', 'vegetables', 'soap') , 0.135
# item: ('cereals', 'milk', 'vegetables') , 0.135
# item: ('toilet paper', 'vegetables', 'waffles') , 0.135
# item: ('hand soap', 'all- purpose') , 0.136
# item: ('juice', 'fruits') , 0.136
# item: ('yogurt', 'hand soap') , 0.136
# item: ('butter', 'flour') , 0.136
# item: ('paper towels', 'pork') , 0.136
# item: ('butter', 'pork') , 0.136
# item: ('flour', 'bagels') , 0.136
# item: ('coffee/tea', 'vegetables', 'lunch meat') , 0.136
# item: ('laundry detergent', 'vegetables', 'juice') , 0.136
# item: ('cereals', 'vegetables', 'pasta') , 0.136
# item: ('coffee/tea', 'cereals', 'vegetables') , 0.136
# item: ('soda', 'vegetables', 'lunch meat') , 0.136
# item: ('butter', 'vegetables', 'eggs') , 0.136
# item: ('milk', 'vegetables', 'laundry detergent') , 0.136
# item: ('sugar', 'vegetables', 'waffles') , 0.136
# item: ('yogurt', 'vegetables', 'bagels') , 0.136
# item: ('coffee/tea', 'vegetables', 'eggs') , 0.136
# item: ('soda', 'vegetables', 'sugar') , 0.136
# item: ('toilet paper', 'vegetables', 'juice') , 0.136
# item: ('sugar', 'sandwich loaves') , 0.137
# item: ('flour', 'sandwich bags') , 0.137
# item: ('soap', 'vegetables', 'spaghetti sauce') , 0.137
# item: ('yogurt', 'vegetables', 'spaghetti sauce') , 0.137
# item: ('dinner rolls', 'shampoo', 'vegetables') , 0.137
# item: ('soda', 'laundry detergent', 'vegetables') , 0.137
# item: ('paper towels', 'vegetables', 'poultry') , 0.137
# item: ('tortillas', 'vegetables', 'poultry') , 0.137
# item: ('dinner rolls', 'vegetables', 'cheeses') , 0.137
# item: ('toilet paper', 'vegetables', 'eggs') , 0.137
# item: ('aluminum foil', 'shampoo', 'vegetables') , 0.137
# item: ('cereals', 'vegetables', 'spaghetti sauce') , 0.137
# item: ('aluminum foil', 'vegetables', 'lunch meat') , 0.137
# item: ('coffee/tea', 'vegetables', 'waffles') , 0.137
# item: ('laundry detergent', 'vegetables', 'dishwashing liquid/detergent') , 0.137
# item: ('soda', 'milk', 'vegetables') , 0.137
# item: ('vegetables', 'waffles', 'juice') , 0.137
# item: ('yogurt', 'vegetables', 'mixes') , 0.137
# item: ('laundry detergent', 'vegetables', 'all- purpose') , 0.137
# item: ('sugar', 'hand soap') , 0.138
# item: ('sugar', 'butter') , 0.138
# item: ('shampoo', 'hand soap') , 0.138
# item: ('hand soap', 'fruits') , 0.138
# item: ('sugar', 'mixes') , 0.138
# item: ('toilet paper', 'pork') , 0.138
# item: ('flour', 'juice') , 0.138
# item: ('sandwich loaves', 'sandwich bags') , 0.138
# item: ('tortillas', 'hand soap') , 0.138
# item: ('hand soap', 'juice') , 0.138
# item: ('flour', 'fruits') , 0.138
# item: ('aluminum foil', 'vegetables', 'eggs') , 0.138
# item: ('vegetables', 'bagels', 'poultry') , 0.138
# item: ('vegetables', 'dishwashing liquid/detergent', 'fruits') , 0.138
# item: ('ice cream', 'vegetables', 'eggs') , 0.138
# item: ('laundry detergent', 'vegetables', 'cheeses') , 0.138
# item: ('dinner rolls', 'vegetables', 'sugar') , 0.138
# item: ('milk', 'vegetables', 'dishwashing liquid/detergent') , 0.138
# item: ('shampoo', 'vegetables', 'juice') , 0.138
# item: ('vegetables', 'waffles', 'spaghetti sauce') , 0.138
# item: ('vegetables', 'lunch meat', 'soap') , 0.138
# item: ('vegetables', 'laundry detergent', 'ice cream') , 0.138
# item: ('yogurt', 'vegetables', 'beef') , 0.138
# item: ('cereals', 'vegetables', 'cheeses') , 0.138
# item: ('paper towels', 'ice cream', 'vegetables') , 0.138
# item: ('hand soap', 'individual meals') , 0.139
# item: ('soda', 'hand soap') , 0.139
# item: ('sandwich loaves', 'hand soap') , 0.139
# item: ('hand soap', 'cheeses') , 0.139
# item: ('cereals', 'hand soap') , 0.139
# item: ('toilet paper', 'hand soap') , 0.139
# item: ('aluminum foil', 'hand soap') , 0.139
# item: ('toilet paper', 'fruits') , 0.139
# item: ('flour', 'paper towels') , 0.139
# item: ('hand soap', 'sandwich bags') , 0.139
# item: ('sugar', 'ketchup') , 0.139
# item: ('ketchup', 'hand soap') , 0.139
# item: ('cereals', 'vegetables', 'dishwashing liquid/detergent') , 0.139
# item: ('vegetables', 'lunch meat', 'spaghetti sauce') , 0.139
# item: ('soda', 'vegetables', 'aluminum foil') , 0.139
# item: ('dinner rolls', 'vegetables', 'dishwashing liquid/detergent') , 0.139
# item: ('vegetables', 'sandwich bags', 'poultry') , 0.139
# item: ('soda', 'vegetables', 'cheeses') , 0.139
# item: ('dinner rolls', 'vegetables', 'lunch meat') , 0.139
# item: ('vegetables', 'spaghetti sauce', 'eggs') , 0.139
# item: ('soda', 'vegetables', 'spaghetti sauce') , 0.139
# item: ('vegetables', 'poultry', 'all- purpose') , 0.139
# item: ('vegetables', 'bagels', 'spaghetti sauce') , 0.139
# item: ('vegetables', 'individual meals', 'poultry') , 0.139
# item: ('sandwich loaves', 'paper towels') , 0.140
# item: ('butter', 'milk') , 0.140
# item: ('coffee/tea', 'hand soap') , 0.140
# item: ('yogurt', 'butter') , 0.140
# item: ('shampoo', 'spaghetti sauce') , 0.140
# item: ('individual meals', 'all- purpose') , 0.140
# item: ('sandwich loaves', 'fruits') , 0.140
# item: ('ice cream', 'vegetables', 'waffles') , 0.140
# item: ('dinner rolls', 'vegetables', 'aluminum foil') , 0.140
# item: ('yogurt', 'laundry detergent', 'vegetables') , 0.140
# item: ('vegetables', 'waffles', 'poultry') , 0.140
# item: ('ice cream', 'pork') , 0.140
# item: ('laundry detergent', 'pork') , 0.140
# item: ('shampoo', 'fruits') , 0.140
# item: ('butter', 'pasta') , 0.140
# item: ('sugar', 'milk') , 0.140
# item: ('yogurt', 'vegetables', 'dishwashing liquid/detergent') , 0.140
# item: ('aluminum foil', 'vegetables', 'cheeses') , 0.140
# item: ('all- purpose', 'vegetables', 'eggs') , 0.140
# item: ('vegetables', 'beef', 'eggs') , 0.140
# item: ('yogurt', 'vegetables', 'lunch meat') , 0.140
# item: ('laundry detergent', 'vegetables', 'sandwich bags') , 0.140
# item: ('ketchup', 'vegetables', 'eggs') , 0.140
# item: ('vegetables', 'lunch meat', 'eggs') , 0.140
# item: ('cereals', 'vegetables', 'lunch meat') , 0.140
# item: ('vegetables', 'waffles', 'soap') , 0.140
# item: ('laundry detergent', 'vegetables', 'eggs') , 0.140
# item: ('sugar', 'paper towels') , 0.141
# item: ('tortillas', 'beef') , 0.141
# item: ('individual meals', 'pork') , 0.141
# item: ('pasta', 'sandwich loaves') , 0.141
# item: ('sandwich loaves', 'flour') , 0.141
# item: ('soda', 'sandwich loaves') , 0.141
# item: ('laundry detergent', 'beef') , 0.141
# item: ('tortillas', 'fruits') , 0.141
# item: ('coffee/tea', 'beef') , 0.141
# item: ('butter', 'sandwich loaves') , 0.141
# item: ('butter', 'fruits') , 0.141
# item: ('sugar', 'vegetables', 'lunch meat') , 0.141
# item: ('vegetables', 'juice', 'spaghetti sauce') , 0.141
# item: ('soda', 'pasta', 'vegetables') , 0.141
# item: ('dinner rolls', 'cereals', 'vegetables') , 0.141
# item: ('soda', 'vegetables', 'soap') , 0.141
# item: ('cereals', 'vegetables', 'mixes') , 0.141
# item: ('sandwich loaves', 'vegetables', 'poultry') , 0.141
# item: ('aluminum foil', 'vegetables', 'waffles') , 0.141
# item: ('yogurt', 'vegetables', 'dinner rolls') , 0.141
# item: ('dinner rolls', 'pasta', 'vegetables') , 0.141
# item: ('sandwich loaves', 'beef') , 0.142
# item: ('flour', 'all- purpose') , 0.142
# item: ('ketchup', 'individual meals') , 0.142
# item: ('shampoo', 'pork') , 0.142
# item: ('pasta', 'lunch meat') , 0.142
# item: ('sandwich loaves', 'tortillas') , 0.142
# item: ('tortillas', 'paper towels') , 0.142
# item: ('tortillas', 'flour') , 0.142
# item: ('toilet paper', 'flour') , 0.142
# item: ('sugar', 'coffee/tea') , 0.142
# item: ('aluminum foil', 'sugar') , 0.142
# item: ('sandwich loaves', 'all- purpose') , 0.142
# item: ('spaghetti sauce', 'pork') , 0.142
# item: ('flour', 'individual meals') , 0.142
# item: ('toilet paper', 'sandwich loaves') , 0.142
# item: ('vegetables', 'bagels', 'dishwashing liquid/detergent') , 0.142
# item: ('soda', 'vegetables', 'waffles') , 0.142
# item: ('yogurt', 'cereals', 'vegetables') , 0.142
# item: ('shampoo', 'vegetables', 'poultry') , 0.142
# item: ('yogurt', 'vegetables', 'all- purpose') , 0.142
# item: ('ketchup', 'butter') , 0.143
# item: ('ketchup', 'lunch meat') , 0.143
# item: ('milk', 'waffles') , 0.143
# item: ('hand soap', 'waffles') , 0.143
# item: ('sandwich bags', 'all- purpose') , 0.143
# item: ('dinner rolls', 'pork') , 0.143
# item: ('hand soap', 'laundry detergent') , 0.143
# item: ('hand soap', 'lunch meat') , 0.143
# item: ('hand soap', 'ice cream') , 0.143
# item: ('hand soap', 'dishwashing liquid/detergent') , 0.143
# item: ('sugar', 'juice') , 0.143
# item: ('shampoo', 'flour') , 0.143
# item: ('milk', 'pork') , 0.143
# item: ('coffee/tea', 'butter') , 0.143
# item: ('tortillas', 'juice') , 0.143
# item: ('toilet paper', 'vegetables', 'poultry') , 0.143
# item: ('dinner rolls', 'laundry detergent', 'vegetables') , 0.143
# item: ('vegetables', 'paper towels', 'eggs') , 0.143
# item: ('vegetables', 'lunch meat', 'dishwashing liquid/detergent') , 0.143
# item: ('dinner rolls', 'vegetables', 'spaghetti sauce') , 0.143
# item: ('vegetables', 'individual meals', 'lunch meat') , 0.143
# item: ('yogurt', 'soda', 'vegetables') , 0.143
# item: ('hand soap', 'eggs') , 0.144
# item: ('butter', 'paper towels') , 0.144
# item: ('hand soap', 'beef') , 0.144
# item: ('individual meals', 'sandwich bags') , 0.144
# item: ('sugar', 'flour') , 0.144
# item: ('coffee/tea', 'fruits') , 0.144
# item: ('pasta', 'fruits') , 0.144
# item: ('soda', 'vegetables', 'poultry') , 0.144
# item: ('vegetables', 'juice', 'eggs') , 0.144
# item: ('vegetables', 'poultry', 'cheeses') , 0.144
# item: ('aluminum foil', 'vegetables', 'juice') , 0.144
# item: ('vegetables', 'sandwich bags', 'cheeses') , 0.144
# item: ('yogurt', 'vegetables', 'cheeses') , 0.144
# item: ('coffee/tea', 'vegetables', 'poultry') , 0.144
# item: ('vegetables', 'mixes', 'dishwashing liquid/detergent') , 0.144
# item: ('vegetables', 'waffles', 'cheeses') , 0.144
# item: ('vegetables', 'waffles', 'dishwashing liquid/detergent') , 0.144
# item: ('pasta', 'vegetables', 'eggs') , 0.144
# item: ('individual meals', 'fruits') , 0.145
# item: ('tortillas', 'cheeses') , 0.145
# item: ('sandwich loaves', 'juice') , 0.145
# item: ('milk', 'individual meals') , 0.145
# item: ('hand soap', 'spaghetti sauce') , 0.145
# item: ('soap', 'pork') , 0.145
# item: ('flour', 'waffles') , 0.145
# item: ('beef', 'all- purpose') , 0.145
# item: ('coffee/tea', 'spaghetti sauce') , 0.145
# item: ('toilet paper', 'sandwich bags') , 0.145
# item: ('flour', 'ice cream') , 0.145
# item: ('sugar', 'spaghetti sauce') , 0.145
# item: ('beef', 'mixes') , 0.145
# item: ('sandwich loaves', 'bagels') , 0.145
# item: ('flour', 'pork') , 0.145
# item: ('yogurt', 'milk', 'vegetables') , 0.145
# item: ('spaghetti sauce', 'vegetables', 'poultry') , 0.145
# item: ('vegetables', 'bagels', 'eggs') , 0.145
# item: ('milk', 'vegetables', 'eggs') , 0.145
# item: ('ice cream', 'vegetables', 'cheeses') , 0.145
# item: ('vegetables', 'waffles', 'eggs') , 0.145
# item: ('sugar', 'all- purpose') , 0.146
# item: ('coffee/tea', 'sandwich loaves') , 0.146
# item: ('milk', 'flour') , 0.146
# item: ('sugar', 'fruits') , 0.146
# item: ('sandwich bags', 'eggs') , 0.146
# item: ('coffee/tea', 'laundry detergent') , 0.146
# item: ('aluminum foil', 'tortillas') , 0.146
# item: ('ketchup', 'tortillas') , 0.146
# item: ('bagels', 'soap') , 0.146
# item: ('tortillas', 'laundry detergent') , 0.146
# item: ('flour', 'laundry detergent') , 0.146
# item: ('tortillas', 'all- purpose') , 0.146
# item: ('shampoo', 'dishwashing liquid/detergent') , 0.146
# item: ('butter', 'shampoo') , 0.146
# item: ('soap', 'vegetables', 'eggs') , 0.146
# item: ('aluminum foil', 'vegetables', 'ice cream') , 0.146
# item: ('aluminum foil', 'vegetables', 'mixes') , 0.146
# item: ('aluminum foil', 'pork') , 0.147
# item: ('sandwich loaves', 'lunch meat') , 0.147
# item: ('shampoo', 'sandwich bags') , 0.147
# item: ('sandwich bags', 'juice') , 0.147
# item: ('spaghetti sauce', 'dishwashing liquid/detergent') , 0.147
# item: ('coffee/tea', 'all- purpose') , 0.147
# item: ('pasta', 'mixes') , 0.147
# item: ('pasta', 'individual meals') , 0.147
# item: ('pasta', 'beef') , 0.147
# item: ('butter', 'tortillas') , 0.147
# item: ('cereals', 'flour') , 0.147
# item: ('sandwich loaves', 'waffles') , 0.147
# item: ('milk', 'fruits') , 0.147
# item: ('yogurt', 'vegetables', 'waffles') , 0.147
# item: ('vegetables', 'juice', 'poultry') , 0.147
# item: ('aluminum foil', 'vegetables', 'bagels') , 0.147
# item: ('dinner rolls', 'vegetables', 'soda') , 0.147
# item: ('milk', 'vegetables', 'poultry') , 0.147
# item: ('soap', 'vegetables', 'poultry') , 0.147
# item: ('yogurt', 'vegetables', 'juice') , 0.147
# item: ('ice cream', 'vegetables', 'lunch meat') , 0.147
# item: ('sandwich bags', 'spaghetti sauce') , 0.147
# item: ('butter', 'all- purpose') , 0.147
# item: ('sandwich loaves', 'mixes') , 0.147
# item: ('beef', 'individual meals') , 0.147
# item: ('mixes', 'soap') , 0.147
# item: ('aluminum foil', 'butter') , 0.147
# item: ('mixes', 'juice') , 0.147
# item: ('laundry detergent', 'paper towels') , 0.147
# item: ('dinner rolls', 'fruits') , 0.147
# item: ('sugar', 'shampoo') , 0.147
# item: ('butter', 'individual meals') , 0.147
# item: ('tortillas', 'ice cream') , 0.147
# item: ('tortillas', 'pork') , 0.147
# item: ('butter', 'juice') , 0.147
# item: ('ketchup', 'fruits') , 0.147
# item: ('pasta', 'sandwich bags') , 0.147
# item: ('sugar', 'tortillas') , 0.147
# item: ('dinner rolls', 'vegetables', 'waffles') , 0.147
# item: ('ketchup', 'cereals') , 0.148
# item: ('all- purpose', 'cheeses') , 0.148
# item: ('laundry detergent', 'fruits') , 0.148
# item: ('soda', 'pork') , 0.148
# item: ('soap', 'fruits') , 0.148
# item: ('tortillas', 'spaghetti sauce') , 0.148
# item: ('pasta', 'hand soap') , 0.148
# item: ('pasta', 'flour') , 0.148
# item: ('ketchup', 'flour') , 0.148
# item: ('butter', 'soap') , 0.148
# item: ('coffee/tea', 'mixes') , 0.148
# item: ('tortillas', 'soap') , 0.148
# item: ('hand soap', 'milk') , 0.148
# item: ('coffee/tea', 'pork') , 0.148
# item: ('sugar', 'individual meals') , 0.148
# item: ('vegetables', 'ice cream', 'poultry') , 0.148
# item: ('aluminum foil', 'vegetables', 'poultry') , 0.148
# item: ('cereals', 'vegetables', 'poultry') , 0.148
# item: ('spaghetti sauce', 'all- purpose') , 0.149
# item: ('toilet paper', 'pasta') , 0.149
# item: ('shampoo', 'milk') , 0.149
# item: ('lunch meat', 'pork') , 0.149
# item: ('mixes', 'fruits') , 0.149
# item: ('sandwich loaves', 'cereals') , 0.149
# item: ('individual meals', 'mixes') , 0.149
# item: ('yogurt', 'soap') , 0.149
# item: ('flour', 'eggs') , 0.149
# item: ('butter', 'dishwashing liquid/detergent') , 0.149
# item: ('soda', 'all- purpose') , 0.149
# item: ('toilet paper', 'mixes') , 0.149
# item: ('dinner rolls', 'sandwich loaves') , 0.149
# item: ('tortillas', 'waffles') , 0.149
# item: ('pasta', 'juice') , 0.149
# item: ('dinner rolls', 'individual meals') , 0.149
# item: ('sugar', 'laundry detergent') , 0.149
# item: ('laundry detergent', 'vegetables', 'poultry') , 0.149
# item: ('juice', 'cheeses') , 0.150
# item: ('soda', 'fruits') , 0.150
# item: ('dinner rolls', 'toilet paper') , 0.150
# item: ('cereals', 'pork') , 0.150
# item: ('sandwich loaves', 'spaghetti sauce') , 0.150
# item: ('butter', 'cereals') , 0.150
# item: ('all- purpose', 'fruits') , 0.150
# item: ('soda', 'shampoo') , 0.150
# item: ('shampoo', 'ice cream') , 0.150
# item: ('paper towels', 'sandwich bags') , 0.150
# item: ('beef', 'pork') , 0.150
# item: ('cheeses', 'pork') , 0.150
# item: ('flour', 'mixes') , 0.150
# item: ('soda', 'mixes') , 0.150
# item: ('shampoo', 'sandwich loaves') , 0.150
# item: ('bagels', 'all- purpose') , 0.150
# item: ('butter', 'spaghetti sauce') , 0.150
# item: ('paper towels', 'fruits') , 0.150
# item: ('aluminum foil', 'sandwich loaves') , 0.150
# item: ('sandwich bags', 'pork') , 0.150
# item: ('vegetables', 'eggs', 'cheeses') , 0.150
# item: ('sugar', 'bagels') , 0.151
# item: ('sugar', 'eggs') , 0.151
# item: ('pasta', 'milk') , 0.151
# item: ('shampoo', 'soap') , 0.151
# item: ('sugar', 'pasta') , 0.151
# item: ('eggs', 'pork') , 0.151
# item: ('aluminum foil', 'sandwich bags') , 0.151
# item: ('paper towels', 'cheeses') , 0.151
# item: ('flour', 'soap') , 0.151
# item: ('yogurt', 'pork') , 0.151
# item: ('cereals', 'all- purpose') , 0.151
# item: ('shampoo', 'pasta') , 0.151
# item: ('ketchup', 'shampoo') , 0.151
# item: ('shampoo', 'eggs') , 0.151
# item: ('cereals', 'vegetables', 'eggs') , 0.151
# item: ('cereals', 'laundry detergent', 'vegetables') , 0.151
# item: ('pasta', 'bagels') , 0.152
# item: ('shampoo', 'individual meals') , 0.152
# item: ('milk', 'all- purpose') , 0.152
# item: ('waffles', 'pork') , 0.152
# item: ('eggs', 'fruits') , 0.152
# item: ('butter', 'bagels') , 0.152
# item: ('tortillas', 'milk') , 0.152
# item: ('shampoo', 'all- purpose') , 0.152
# item: ('tortillas', 'dishwashing liquid/detergent') , 0.152
# item: ('coffee/tea', 'flour') , 0.152
# item: ('toilet paper', 'spaghetti sauce') , 0.152
# item: ('coffee/tea', 'milk') , 0.152
# item: ('hand soap', 'mixes') , 0.152
# item: ('mixes', 'all- purpose') , 0.152
# item: ('flour', 'dishwashing liquid/detergent') , 0.152
# item: ('butter', 'waffles') , 0.152
# item: ('sugar', 'dishwashing liquid/detergent') , 0.152
# item: ('sugar', 'toilet paper') , 0.152
# item: ('coffee/tea', 'bagels') , 0.152
# item: ('yogurt', 'paper towels') , 0.152
# item: ('laundry detergent', 'individual meals') , 0.152
# item: ('dinner rolls', 'butter') , 0.152
# item: ('yogurt', 'vegetables', 'aluminum foil') , 0.152
# item: ('sugar', 'vegetables', 'poultry') , 0.152
# item: ('coffee/tea', 'sandwich bags') , 0.153
# item: ('yogurt', 'tortillas') , 0.153
# item: ('yogurt', 'sandwich loaves') , 0.153
# item: ('sandwich bags', 'lunch meat') , 0.153
# item: ('ketchup', 'sandwich loaves') , 0.153
# item: ('butter', 'mixes') , 0.153
# item: ('yogurt', 'ketchup') , 0.153
# item: ('ketchup', 'paper towels') , 0.153
# item: ('pasta', 'tortillas') , 0.153
# item: ('laundry detergent', 'bagels') , 0.153
# item: ('toilet paper', 'dishwashing liquid/detergent') , 0.153
# item: ('coffee/tea', 'shampoo') , 0.153
# item: ('toilet paper', 'laundry detergent') , 0.153
# item: ('coffee/tea', 'individual meals') , 0.153
# item: ('tortillas', 'individual meals') , 0.153
# item: ('juice', 'dishwashing liquid/detergent') , 0.153
# item: ('toilet paper', 'individual meals') , 0.153
# item: ('sugar', 'cheeses') , 0.153
# item: ('dinner rolls', 'sandwich bags') , 0.153
# item: ('dishwashing liquid/detergent', 'pork') , 0.153
# item: ('yogurt', 'vegetables', 'poultry') , 0.153
# item: ('ketchup', 'pork') , 0.154
# item: ('milk', 'juice') , 0.154
# item: ('sandwich bags', 'dishwashing liquid/detergent') , 0.154
# item: ('butter', 'ice cream') , 0.154
# item: ('paper towels', 'bagels') , 0.154
# item: ('pasta', 'laundry detergent') , 0.154
# item: ('all- purpose', 'pork') , 0.154
# item: ('dinner rolls', 'hand soap') , 0.154
# item: ('ice cream', 'mixes') , 0.154
# item: ('coffee/tea', 'dishwashing liquid/detergent') , 0.154
# item: ('juice', 'all- purpose') , 0.154
# item: ('toilet paper', 'all- purpose') , 0.154
# item: ('coffee/tea', 'paper towels') , 0.154
# item: ('shampoo', 'beef') , 0.154
# item: ('butter', 'sandwich bags') , 0.154
# item: ('individual meals', 'eggs') , 0.154
# item: ('shampoo', 'laundry detergent') , 0.154
# item: ('lunch meat', 'mixes') , 0.154
# item: ('sandwich bags', 'fruits') , 0.154
# item: ('vegetables', 'dishwashing liquid/detergent', 'eggs') , 0.154
# item: ('laundry detergent', 'soap') , 0.155
# item: ('paper towels', 'soap') , 0.155
# item: ('dinner rolls', 'flour') , 0.155
# item: ('paper towels', 'individual meals') , 0.155
# item: ('mixes', 'waffles') , 0.155
# item: ('coffee/tea', 'tortillas') , 0.155
# item: ('bagels', 'sandwich bags') , 0.155
# item: ('soda', 'butter') , 0.155
# item: ('ketchup', 'spaghetti sauce') , 0.155
# item: ('aluminum foil', 'flour') , 0.155
# item: ('hand soap', 'poultry') , 0.155
# item: ('butter', 'toilet paper') , 0.155
# item: ('ketchup', 'all- purpose') , 0.155
# item: ('dinner rolls', 'beef') , 0.155
# item: ('yogurt', 'sandwich bags') , 0.155
# item: ('sugar', 'soap') , 0.155
# item: ('mixes', 'pork') , 0.155
# item: ('individual meals', 'juice') , 0.155
# item: ('dinner rolls', 'bagels') , 0.155
# item: ('shampoo', 'waffles') , 0.155
# item: ('bagels', 'pork') , 0.155
# item: ('paper towels', 'beef') , 0.155
# item: ('dinner rolls', 'all- purpose') , 0.155
# item: ('ketchup', 'dishwashing liquid/detergent') , 0.155
# item: ('coffee/tea', 'pasta') , 0.155
# item: ('laundry detergent', 'juice') , 0.155
# item: ('soda', 'tortillas') , 0.155
# item: ('beef', 'juice') , 0.155
# item: ('sandwich bags', 'mixes') , 0.155
# item: ('sandwich loaves', 'cheeses') , 0.155
# item: ('spaghetti sauce', 'fruits') , 0.155
# item: ('ketchup', 'beef') , 0.155
# item: ('shampoo', 'paper towels') , 0.155
# item: ('sugar', 'beef') , 0.155
# item: ('yogurt', 'ice cream') , 0.155
# item: ('soda', 'beef') , 0.155
# item: ('dinner rolls', 'paper towels') , 0.155
# item: ('vegetables', 'poultry', 'eggs') , 0.155
# item: ('cereals', 'juice') , 0.156
# item: ('ketchup', 'ice cream') , 0.156
# item: ('dinner rolls', 'soap') , 0.156
# item: ('shampoo', 'mixes') , 0.156
# item: ('ketchup', 'milk') , 0.156
# item: ('soda', 'cereals') , 0.156
# item: ('ketchup', 'pasta') , 0.156
# item: ('beef', 'sandwich bags') , 0.156
# item: ('juice', 'soap') , 0.156
# item: ('paper towels', 'all- purpose') , 0.156
# item: ('coffee/tea', 'toilet paper') , 0.156
# item: ('coffee/tea', 'juice') , 0.156
# item: ('yogurt', 'flour') , 0.156
# item: ('sugar', 'cereals') , 0.156
# item: ('juice', 'pork') , 0.156
# item: ('aluminum foil', 'spaghetti sauce') , 0.156
# item: ('milk', 'cheeses') , 0.156
# item: ('individual meals', 'waffles') , 0.156
# item: ('dinner rolls', 'milk') , 0.156
# item: ('ketchup', 'toilet paper') , 0.156
# item: ('paper towels', 'spaghetti sauce') , 0.156
# item: ('ice cream', 'sandwich bags') , 0.156
# item: ('laundry detergent', 'waffles') , 0.156
# item: ('beef', 'bagels') , 0.156
# item: ('toilet paper', 'tortillas') , 0.156
# item: ('paper towels', 'waffles') , 0.156
# item: ('flour', 'lunch meat') , 0.156
# item: ('dinner rolls', 'vegetables', 'eggs') , 0.156
# item: ('vegetables', 'mixes', 'poultry') , 0.156
# item: ('aluminum foil', 'all- purpose') , 0.157
# item: ('aluminum foil', 'soap') , 0.157
# item: ('aluminum foil', 'pasta') , 0.157
# item: ('ketchup', 'laundry detergent') , 0.157
# item: ('ice cream', 'all- purpose') , 0.157
# item: ('sugar', 'ice cream') , 0.157
# item: ('laundry detergent', 'lunch meat') , 0.157
# item: ('soda', 'bagels') , 0.157
# item: ('toilet paper', 'shampoo') , 0.157
# item: ('toilet paper', 'beef') , 0.157
# item: ('beef', 'dishwashing liquid/detergent') , 0.157
# item: ('flour', 'poultry') , 0.157
# item: ('dinner rolls', 'juice') , 0.157
# item: ('beef', 'waffles') , 0.157
# item: ('aluminum foil', 'eggs') , 0.157
# item: ('soda', 'juice') , 0.157
# item: ('yogurt', 'vegetables', 'eggs') , 0.157
# item: ('vegetables', 'lunch meat', 'waffles') , 0.157
# item: ('aluminum foil', 'ketchup') , 0.158
# item: ('dinner rolls', 'tortillas') , 0.158
# item: ('cereals', 'sandwich bags') , 0.158
# item: ('aluminum foil', 'fruits') , 0.158
# item: ('butter', 'laundry detergent') , 0.158
# item: ('milk', 'sandwich bags') , 0.158
# item: ('beef', 'lunch meat') , 0.158
# item: ('sandwich loaves', 'soap') , 0.158
# item: ('soda', 'flour') , 0.158
# item: ('yogurt', 'laundry detergent') , 0.158
# item: ('sandwich loaves', 'ice cream') , 0.158
# item: ('individual meals', 'spaghetti sauce') , 0.158
# item: ('milk', 'spaghetti sauce') , 0.158
# item: ('bagels', 'lunch meat') , 0.158
# item: ('shampoo', 'bagels') , 0.158
# item: ('mixes', 'spaghetti sauce') , 0.158
# item: ('yogurt', 'individual meals') , 0.158
# item: ('dinner rolls', 'ketchup') , 0.158
# item: ('beef', 'spaghetti sauce') , 0.158
# item: ('shampoo', 'cheeses') , 0.158
# item: ('yogurt', 'fruits') , 0.158
# item: ('yogurt', 'dishwashing liquid/detergent') , 0.158
# item: ('yogurt', 'shampoo') , 0.158
# item: ('soda', 'ketchup') , 0.158
# item: ('ketchup', 'bagels') , 0.158
# item: ('paper towels', 'mixes') , 0.158
# item: ('vegetables', 'lunch meat', 'poultry') , 0.158
# item: ('soda', 'vegetables', 'eggs') , 0.158
# item: ('yogurt', 'pasta') , 0.159
# item: ('aluminum foil', 'dishwashing liquid/detergent') , 0.159
# item: ('coffee/tea', 'eggs') , 0.159
# item: ('laundry detergent', 'ice cream') , 0.159
# item: ('mixes', 'eggs') , 0.159
# item: ('butter', 'eggs') , 0.159
# item: ('soda', 'coffee/tea') , 0.159
# item: ('shampoo', 'cereals') , 0.159
# item: ('aluminum foil', 'coffee/tea') , 0.159
# item: ('milk', 'mixes') , 0.159
# item: ('sugar', 'yogurt') , 0.159
# item: ('sandwich bags', 'soap') , 0.159
# item: ('paper towels', 'poultry') , 0.159
# item: ('paper towels', 'juice') , 0.159
# item: ('paper towels', 'dishwashing liquid/detergent') , 0.159
# item: ('ice cream', 'spaghetti sauce') , 0.159
# item: ('cereals', 'tortillas') , 0.159
# item: ('sandwich bags', 'waffles') , 0.159
# item: ('tortillas', 'eggs') , 0.159
# item: ('lunch meat', 'eggs') , 0.159
# item: ('coffee/tea', 'soap') , 0.159
# item: ('individual meals', 'dishwashing liquid/detergent') , 0.159
# item: ('aluminum foil', 'shampoo') , 0.159
# item: ('dinner rolls', 'coffee/tea') , 0.159
# item: ('shampoo', 'lunch meat') , 0.160
# item: ('sandwich loaves', 'individual meals') , 0.160
# item: ('pasta', 'soap') , 0.160
# item: ('butter', 'lunch meat') , 0.160
# item: ('soap', 'dishwashing liquid/detergent') , 0.160
# item: ('all- purpose', 'eggs') , 0.160
# item: ('aluminum foil', 'beef') , 0.160
# item: ('sugar', 'waffles') , 0.160
# item: ('pasta', 'all- purpose') , 0.160
# item: ('beef', 'cheeses') , 0.160
# item: ('beef', 'soap') , 0.160
# item: ('individual meals', 'soap') , 0.160
# item: ('aluminum foil', 'paper towels') , 0.160
# item: ('pasta', 'spaghetti sauce') , 0.160
# item: ('pasta', 'cheeses') , 0.160
# item: ('soda', 'lunch meat') , 0.160
# item: ('butter', 'cheeses') , 0.160
# item: ('bagels', 'waffles') , 0.160
# item: ('toilet paper', 'ice cream') , 0.160
# item: ('ice cream', 'bagels') , 0.160
# item: ('cereals', 'individual meals') , 0.160
# item: ('aluminum foil', 'toilet paper') , 0.160
# item: ('lunch meat', 'all- purpose') , 0.160
# item: ('laundry detergent', 'mixes') , 0.160
# item: ('flour', 'cheeses') , 0.160
# item: ('yogurt', 'spaghetti sauce') , 0.160
# item: ('vegetables', 'poultry', 'dishwashing liquid/detergent') , 0.160
# item: ('aluminum foil', 'laundry detergent') , 0.161
# item: ('ketchup', 'juice') , 0.161
# item: ('aluminum foil', 'lunch meat') , 0.161
# item: ('milk', 'lunch meat') , 0.161
# item: ('aluminum foil', 'milk') , 0.161
# item: ('soda', 'paper towels') , 0.161
# item: ('laundry detergent', 'cheeses') , 0.161
# item: ('ketchup', 'cheeses') , 0.161
# item: ('yogurt', 'lunch meat') , 0.161
# item: ('tortillas', 'sandwich bags') , 0.161
# item: ('lunch meat', 'cheeses') , 0.161
# item: ('milk', 'beef') , 0.161
# item: ('yogurt', 'coffee/tea') , 0.161
# item: ('soap', 'spaghetti sauce') , 0.161
# item: ('yogurt', 'beef') , 0.161
# item: ('dishwashing liquid/detergent', 'all- purpose') , 0.161
# item: ('cereals', 'waffles') , 0.161
# item: ('individual meals', 'cheeses') , 0.161
# item: ('milk', 'bagels') , 0.162
# item: ('cereals', 'fruits') , 0.162
# item: ('ketchup', 'waffles') , 0.162
# item: ('pasta', 'poultry') , 0.162
# item: ('pasta', 'dishwashing liquid/detergent') , 0.162
# item: ('pasta', 'cereals') , 0.162
# item: ('pasta', 'waffles') , 0.162
# item: ('toilet paper', 'paper towels') , 0.162
# item: ('laundry detergent', 'spaghetti sauce') , 0.162
# item: ('lunch meat', 'juice') , 0.162
# item: ('soda', 'aluminum foil') , 0.162
# item: ('ice cream', 'beef') , 0.162
# item: ('milk', 'paper towels') , 0.162
# item: ('sugar', 'lunch meat') , 0.162
# item: ('milk', 'soap') , 0.162
# item: ('dinner rolls', 'ice cream') , 0.162
# item: ('dinner rolls', 'vegetables', 'poultry') , 0.162
# item: ('yogurt', 'toilet paper') , 0.162
# item: ('yogurt', 'bagels') , 0.162
# item: ('bagels', 'juice') , 0.162
# item: ('ice cream', 'individual meals') , 0.162
# item: ('cereals', 'bagels') , 0.162
# item: ('dinner rolls', 'lunch meat') , 0.162
# item: ('soda', 'sandwich bags') , 0.162
# item: ('tortillas', 'mixes') , 0.162
# item: ('soda', 'toilet paper') , 0.162
# item: ('soap', 'cheeses') , 0.162
# item: ('cereals', 'soap') , 0.162
# item: ('aluminum foil', 'individual meals') , 0.162
# item: ('soda', 'sugar') , 0.162
# item: ('tortillas', 'bagels') , 0.162
# item: ('dinner rolls', 'mixes') , 0.162
# item: ('laundry detergent', 'all- purpose') , 0.162
# item: ('lunch meat', 'fruits') , 0.163
# item: ('spaghetti sauce', 'eggs') , 0.163
# item: ('laundry detergent', 'dishwashing liquid/detergent') , 0.163
# item: ('sandwich loaves', 'poultry') , 0.163
# item: ('toilet paper', 'eggs') , 0.163
# item: ('waffles', 'fruits') , 0.163
# item: ('toilet paper', 'bagels') , 0.163
# item: ('beef', 'eggs') , 0.163
# item: ('laundry detergent', 'sandwich bags') , 0.163
# item: ('soda', 'laundry detergent') , 0.163
# item: ('soap', 'all- purpose') , 0.163
# item: ('tortillas', 'lunch meat') , 0.163
# item: ('cheeses', 'fruits') , 0.163
# item: ('laundry detergent', 'eggs') , 0.163
# item: ('dishwashing liquid/detergent', 'cheeses') , 0.163
# item: ('toilet paper', 'milk') , 0.163
# item: ('mixes', 'cheeses') , 0.163
# item: ('yogurt', 'mixes') , 0.164
# item: ('toilet paper', 'soap') , 0.164
# item: ('poultry', 'pork') , 0.164
# item: ('ketchup', 'soap') , 0.164
# item: ('dinner rolls', 'sugar') , 0.164
# item: ('ketchup', 'sandwich bags') , 0.164
# item: ('bagels', 'mixes') , 0.164
# item: ('coffee/tea', 'ketchup') , 0.164
# item: ('toilet paper', 'lunch meat') , 0.164
# item: ('cereals', 'paper towels') , 0.164
# item: ('waffles', 'spaghetti sauce') , 0.164
# item: ('pasta', 'paper towels') , 0.164
# item: ('milk', 'ice cream') , 0.165
# item: ('ice cream', 'dishwashing liquid/detergent') , 0.165
# item: ('ice cream', 'fruits') , 0.165
# item: ('ketchup', 'poultry') , 0.165
# item: ('paper towels', 'lunch meat') , 0.165
# item: ('spaghetti sauce', 'cheeses') , 0.165
# item: ('ketchup', 'mixes') , 0.165
# item: ('dinner rolls', 'laundry detergent') , 0.165
# item: ('juice', 'eggs') , 0.165
# item: ('individual meals', 'bagels') , 0.165
# item: ('dinner rolls', 'dishwashing liquid/detergent') , 0.165
# item: ('coffee/tea', 'ice cream') , 0.165
# item: ('aluminum foil', 'cereals') , 0.166
# item: ('lunch meat', 'soap') , 0.166
# item: ('milk', 'laundry detergent') , 0.166
# item: ('cereals', 'ice cream') , 0.166
# item: ('dinner rolls', 'aluminum foil') , 0.166
# item: ('paper towels', 'eggs') , 0.166
# item: ('ketchup', 'eggs') , 0.166
# item: ('beef', 'fruits') , 0.166
# item: ('butter', 'poultry') , 0.166
# item: ('dinner rolls', 'yogurt') , 0.166
# item: ('soda', 'individual meals') , 0.166
# item: ('toilet paper', 'cereals') , 0.166
# item: ('soap', 'eggs') , 0.167
# item: ('ice cream', 'soap') , 0.167
# item: ('cereals', 'spaghetti sauce') , 0.167
# item: ('ice cream', 'eggs') , 0.167
# item: ('coffee/tea', 'lunch meat') , 0.167
# item: ('ice cream', 'juice') , 0.167
# item: ('soda', 'yogurt') , 0.167
# item: ('soda', 'dishwashing liquid/detergent') , 0.167
# item: ('bagels', 'spaghetti sauce') , 0.167
# item: ('waffles', 'poultry') , 0.167
# item: ('waffles', 'juice') , 0.167
# item: ('yogurt', 'all- purpose') , 0.167
# item: ('pasta', 'ice cream') , 0.168
# item: ('coffee/tea', 'cheeses') , 0.168
# item: ('poultry', 'fruits') , 0.168
# item: ('bagels', 'cheeses') , 0.168
# item: ('soda', 'spaghetti sauce') , 0.168
# item: ('bagels', 'eggs') , 0.168
# item: ('dinner rolls', 'cheeses') , 0.168
# item: ('bagels', 'fruits') , 0.168
# item: ('bagels', 'poultry') , 0.168
# item: ('yogurt', 'milk') , 0.168
# item: ('bagels', 'dishwashing liquid/detergent') , 0.168
# item: ('waffles', 'all- purpose') , 0.168
# item: ('dishwashing liquid/detergent', 'fruits') , 0.168
# item: ('toilet paper', 'cheeses') , 0.168
# item: ('cereals', 'lunch meat') , 0.169
# item: ('soda', 'cheeses') , 0.169
# item: ('milk', 'eggs') , 0.169
# item: ('lunch meat', 'spaghetti sauce') , 0.169
# item: ('cereals', 'beef') , 0.169
# item: ('aluminum foil', 'bagels') , 0.169
# item: ('soda', 'ice cream') , 0.169
# item: ('cereals', 'laundry detergent') , 0.169
# item: ('dinner rolls', 'waffles') , 0.169
# item: ('soda', 'pasta') , 0.169
# item: ('coffee/tea', 'cereals') , 0.169
# item: ('sandwich bags', 'cheeses') , 0.169
# item: ('dinner rolls', 'shampoo') , 0.169
# item: ('aluminum foil', 'cheeses') , 0.169
# item: ('waffles', 'eggs') , 0.169
# item: ('pasta', 'eggs') , 0.169
# item: ('cereals', 'dishwashing liquid/detergent') , 0.169
# item: ('aluminum foil', 'waffles') , 0.169
# item: ('eggs', 'cheeses') , 0.169
# item: ('shampoo', 'juice') , 0.170
# item: ('beef', 'poultry') , 0.170
# item: ('milk', 'dishwashing liquid/detergent') , 0.170
# item: ('individual meals', 'poultry') , 0.170
# item: ('ice cream', 'paper towels') , 0.170
# item: ('dinner rolls', 'cereals') , 0.171
# item: ('shampoo', 'poultry') , 0.171
# item: ('dinner rolls', 'soda') , 0.171
# item: ('spaghetti sauce', 'poultry') , 0.171
# item: ('tortillas', 'poultry') , 0.171
# item: ('toilet paper', 'poultry') , 0.171
# item: ('dishwashing liquid/detergent', 'eggs') , 0.171
# item: ('dinner rolls', 'spaghetti sauce') , 0.172
# item: ('coffee/tea', 'waffles') , 0.172
# item: ('yogurt', 'cereals') , 0.172
# item: ('sandwich bags', 'poultry') , 0.172
# item: ('yogurt', 'cheeses') , 0.172
# item: ('juice', 'spaghetti sauce') , 0.172
# item: ('aluminum foil', 'juice') , 0.172
# item: ('toilet paper', 'juice') , 0.172
# item: ('aluminum foil', 'mixes') , 0.172
# item: ('waffles', 'cheeses') , 0.173
# item: ('ice cream', 'waffles') , 0.173
# item: ('dinner rolls', 'pasta') , 0.173
# item: ('soda', 'poultry') , 0.173
# item: ('waffles', 'soap') , 0.173
# item: ('soda', 'milk') , 0.173
# item: ('toilet paper', 'waffles') , 0.173
# item: ('cereals', 'mixes') , 0.174
# item: ('dinner rolls', 'eggs') , 0.174
# item: ('yogurt', 'waffles') , 0.174
# item: ('cereals', 'milk') , 0.174
# ...
# Rule: ('paper towels', 'lunch meat') ==> ('vegetables',) , 0.819
# Rule: ('ketchup', 'beef') ==> ('vegetables',) , 0.819
# Rule: ('shampoo', 'waffles') ==> ('vegetables',) , 0.819
# Rule: ('shampoo', 'paper towels') ==> ('vegetables',) , 0.819
# Rule: ('aluminum foil', 'milk') ==> ('vegetables',) , 0.820
# Rule: ('milk', 'lunch meat') ==> ('vegetables',) , 0.820
# Rule: ('individual meals', 'cheeses') ==> ('vegetables',) , 0.820
# Rule: ('waffles', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.820
# Rule: ('milk', 'laundry detergent') ==> ('vegetables',) , 0.820
# Rule: ('dinner rolls', 'milk') ==> ('vegetables',) , 0.820
# Rule: ('juice', 'soap') ==> ('vegetables',) , 0.820
# Rule: ('paper towels', 'spaghetti sauce') ==> ('vegetables',) , 0.820
# Rule: ('dinner rolls', 'soap') ==> ('vegetables',) , 0.820
# Rule: ('cereals', 'poultry') ==> ('vegetables',) , 0.820
# Rule: ('ketchup', 'waffles') ==> ('vegetables',) , 0.821
# Rule: ('ice cream', 'beef') ==> ('vegetables',) , 0.821
# Rule: ('cereals', 'spaghetti sauce') ==> ('vegetables',) , 0.821
# Rule: ('waffles', 'juice') ==> ('vegetables',) , 0.821
# Rule: ('flour', 'poultry') ==> ('vegetables',) , 0.821
# Rule: ('beef', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.821
# Rule: ('soda', 'bagels') ==> ('vegetables',) , 0.821
# Rule: ('juice', 'spaghetti sauce') ==> ('vegetables',) , 0.821
# Rule: ('bagels', 'juice') ==> ('vegetables',) , 0.822
# Rule: ('soap', 'cheeses') ==> ('vegetables',) , 0.822
# Rule: ('butter', 'mixes') ==> ('vegetables',) , 0.822
# Rule: ('bagels', 'poultry') ==> ('vegetables',) , 0.822
# Rule: ('dishwashing liquid/detergent', 'fruits') ==> ('vegetables',) , 0.822
# Rule: ('soda', 'flour') ==> ('vegetables',) , 0.822
# Rule: ('aluminum foil', 'ketchup') ==> ('vegetables',) , 0.822
# Rule: ('aluminum foil', 'fruits') ==> ('vegetables',) , 0.822
# Rule: ('milk', 'poultry') ==> ('vegetables',) , 0.823
# Rule: ('dinner rolls', 'hand soap') ==> ('vegetables',) , 0.823
# Rule: ('paper towels', 'bagels') ==> ('vegetables',) , 0.823
# Rule: ('sandwich bags', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.823
# Rule: ('lunch meat', 'spaghetti sauce') ==> ('vegetables',) , 0.823
# Rule: ('soda', 'cheeses') ==> ('vegetables',) , 0.823
# Rule: ('aluminum foil', 'coffee/tea') ==> ('vegetables',) , 0.823
# Rule: ('lunch meat', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.823
# Rule: ('cereals', 'paper towels') ==> ('vegetables',) , 0.824
# Rule: ('ketchup', 'sandwich bags') ==> ('vegetables',) , 0.824
# Rule: ('ketchup', 'soap') ==> ('vegetables',) , 0.824
# Rule: ('sandwich bags', 'bagels') ==> ('vegetables',) , 0.824
# Rule: ('mixes', 'waffles') ==> ('vegetables',) , 0.824
# Rule: ('sugar', 'soap') ==> ('vegetables',) , 0.824
# Rule: ('coffee/tea', 'poultry') ==> ('vegetables',) , 0.824
# Rule: ('aluminum foil', 'toilet paper') ==> ('vegetables',) , 0.824
# Rule: ('sugar',) ==> ('vegetables',) , 0.825
# Rule: ('sandwich loaves', 'cheeses') ==> ('vegetables',) , 0.825
# Rule: ('yogurt', 'coffee/tea') ==> ('vegetables',) , 0.825
# Rule: ('dinner rolls', 'cereals') ==> ('vegetables',) , 0.826
# Rule: ('paper towels', 'waffles') ==> ('vegetables',) , 0.826
# Rule: ('ice cream', 'sandwich bags') ==> ('vegetables',) , 0.826
# Rule: ('ketchup', 'toilet paper') ==> ('vegetables',) , 0.826
# Rule: ('aluminum foil', 'ice cream') ==> ('vegetables',) , 0.826
# Rule: ('ice cream', 'eggs') ==> ('vegetables',) , 0.826
# Rule: ('yogurt', 'cereals') ==> ('vegetables',) , 0.827
# Rule: ('tortillas', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.827
# Rule: ('laundry detergent', 'lunch meat') ==> ('vegetables',) , 0.827
# Rule: ('dinner rolls', 'mixes') ==> ('vegetables',) , 0.827
# Rule: ('soda', 'spaghetti sauce') ==> ('vegetables',) , 0.827
# Rule: ('toilet paper', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.828
# Rule: ('yogurt', 'shampoo') ==> ('vegetables',) , 0.828
# Rule: ('ice cream', 'poultry') ==> ('vegetables',) , 0.828
# Rule: ('coffee/tea', 'paper towels') ==> ('vegetables',) , 0.829
# Rule: ('butter', 'sandwich bags') ==> ('vegetables',) , 0.829
# Rule: ('paper towels', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.829
# Rule: ('dinner rolls', 'poultry') ==> ('vegetables',) , 0.829
# Rule: ('aluminum foil', 'cheeses') ==> ('vegetables',) , 0.829
# Rule: ('bagels', 'waffles') ==> ('vegetables',) , 0.830
# Rule: ('aluminum foil', 'beef') ==> ('vegetables',) , 0.830
# Rule: ('shampoo', 'lunch meat') ==> ('vegetables',) , 0.830
# Rule: ('soda', 'paper towels') ==> ('vegetables',) , 0.831
# Rule: ('ketchup', 'juice') ==> ('vegetables',) , 0.831
# Rule: ('yogurt',) ==> ('vegetables',) , 0.831
# Rule: ('lunch meat', 'soap') ==> ('vegetables',) , 0.831
# Rule: ('shampoo', 'poultry') ==> ('vegetables',) , 0.831
# Rule: ('juice', 'poultry') ==> ('vegetables',) , 0.831
# Rule: ('yogurt', 'juice') ==> ('vegetables',) , 0.831
# Rule: ('sugar', 'bagels') ==> ('vegetables',) , 0.831
# Rule: ('yogurt', 'pork') ==> ('vegetables',) , 0.831
# Rule: ('aluminum foil', 'spaghetti sauce') ==> ('vegetables',) , 0.831
# Rule: ('coffee/tea', 'juice') ==> ('vegetables',) , 0.831
# Rule: ('individual meals', 'waffles') ==> ('vegetables',) , 0.831
# Rule: ('laundry detergent', 'spaghetti sauce') ==> ('vegetables',) , 0.832
# Rule: ('pasta', 'poultry') ==> ('vegetables',) , 0.832
# Rule: ('lunch meat', 'juice') ==> ('vegetables',) , 0.832
# Rule: ('bagels', 'spaghetti sauce') ==> ('vegetables',) , 0.832
# Rule: ('dinner rolls', 'spaghetti sauce') ==> ('vegetables',) , 0.832
# Rule: ('beef', 'waffles') ==> ('vegetables',) , 0.832
# Rule: ('aluminum foil', 'all- purpose') ==> ('vegetables',) , 0.832
# Rule: ('soda', 'poultry') ==> ('vegetables',) , 0.832
# Rule: ('waffles', 'cheeses') ==> ('vegetables',) , 0.832
# Rule: ('beef', 'lunch meat') ==> ('vegetables',) , 0.833
# Rule: ('sugar', 'cheeses') ==> ('vegetables',) , 0.833
# Rule: ('yogurt', 'fruits') ==> ('vegetables',) , 0.833
# Rule: ('cereals', 'lunch meat') ==> ('vegetables',) , 0.833
# Rule: ('soda', 'pasta') ==> ('vegetables',) , 0.834
# Rule: ('aluminum foil', 'waffles') ==> ('vegetables',) , 0.834
# Rule: ('yogurt', 'mixes') ==> ('vegetables',) , 0.834
# Rule: ('tortillas', 'eggs') ==> ('vegetables',) , 0.834
# Rule: ('cereals', 'shampoo') ==> ('vegetables',) , 0.834
# Rule: ('mixes', 'eggs') ==> ('vegetables',) , 0.834
# Rule: ('sandwich bags', 'waffles') ==> ('vegetables',) , 0.834
# Rule: ('aluminum foil', 'paper towels') ==> ('vegetables',) , 0.835
# Rule: ('sandwich loaves', 'individual meals') ==> ('vegetables',) , 0.835
# Rule: ('aluminum foil', 'flour') ==> ('vegetables',) , 0.835
# Rule: ('dinner rolls', 'flour') ==> ('vegetables',) , 0.835
# Rule: ('toilet paper', 'poultry') ==> ('vegetables',) , 0.836
# Rule: ('aluminum foil', 'laundry detergent') ==> ('vegetables',) , 0.836
# Rule: ('cereals', 'waffles') ==> ('vegetables',) , 0.836
# Rule: ('yogurt', 'ice cream') ==> ('vegetables',) , 0.836
# Rule: ('flour', 'mixes') ==> ('vegetables',) , 0.836
# Rule: ('paper towels', 'sandwich bags') ==> ('vegetables',) , 0.836
# Rule: ('aluminum foil', 'juice') ==> ('vegetables',) , 0.837
# Rule: ('yogurt', 'cheeses') ==> ('vegetables',) , 0.837
# Rule: ('waffles', 'poultry') ==> ('vegetables',) , 0.837
# Rule: ('paper towels', 'cheeses') ==> ('vegetables',) , 0.837
# Rule: ('eggs',) ==> ('vegetables',) , 0.838
# Rule: ('yogurt', 'bagels') ==> ('vegetables',) , 0.838
# Rule: ('soda', 'sugar') ==> ('vegetables',) , 0.838
# Rule: ('soda', 'laundry detergent') ==> ('vegetables',) , 0.839
# Rule: ('toilet paper', 'eggs') ==> ('vegetables',) , 0.839
# Rule: ('laundry detergent', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.839
# Rule: ('shampoo', 'cheeses') ==> ('vegetables',) , 0.839
# Rule: ('bagels', 'lunch meat') ==> ('vegetables',) , 0.839
# Rule: ('sandwich loaves', 'soap') ==> ('vegetables',) , 0.839
# Rule: ('dinner rolls', 'sandwich bags') ==> ('vegetables',) , 0.839
# Rule: ('laundry detergent', 'bagels') ==> ('vegetables',) , 0.839
# Rule: ('juice', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.839
# Rule: ('dinner rolls', 'sugar') ==> ('vegetables',) , 0.840
# Rule: ('waffles', 'spaghetti sauce') ==> ('vegetables',) , 0.840
# Rule: ('paper towels', 'juice') ==> ('vegetables',) , 0.840
# Rule: ('yogurt', 'sugar') ==> ('vegetables',) , 0.840
# Rule: ('dinner rolls', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.840
# Rule: ('laundry detergent', 'mixes') ==> ('vegetables',) , 0.841
# Rule: ('pasta', 'cheeses') ==> ('vegetables',) , 0.841
# Rule: ('yogurt', 'soap') ==> ('vegetables',) , 0.841
# Rule: ('toilet paper', 'mixes') ==> ('vegetables',) , 0.841
# Rule: ('dinner rolls', 'aluminum foil') ==> ('vegetables',) , 0.841
# Rule: ('ketchup', 'cheeses') ==> ('vegetables',) , 0.842
# Rule: ('lunch meat', 'cheeses') ==> ('vegetables',) , 0.842
# Rule: ('sugar', 'beef') ==> ('vegetables',) , 0.842
# Rule: ('cereals', 'pasta') ==> ('vegetables',) , 0.842
# Rule: ('sugar', 'cereals') ==> ('vegetables',) , 0.843
# Rule: ('yogurt', 'flour') ==> ('vegetables',) , 0.843
# Rule: ('aluminum foil', 'sandwich bags') ==> ('vegetables',) , 0.843
# Rule: ('laundry detergent', 'all- purpose') ==> ('vegetables',) , 0.843
# Rule: ('yogurt', 'waffles') ==> ('vegetables',) , 0.843
# Rule: ('ice cream', 'lunch meat') ==> ('vegetables',) , 0.843
# Rule: ('dinner rolls', 'juice') ==> ('vegetables',) , 0.844
# Rule: ('ketchup', 'laundry detergent') ==> ('vegetables',) , 0.844
# Rule: ('sugar', 'ice cream') ==> ('vegetables',) , 0.844
# Rule: ('aluminum foil', 'pasta') ==> ('vegetables',) , 0.844
# Rule: ('sugar', 'toilet paper') ==> ('vegetables',) , 0.844
# Rule: ('butter', 'laundry detergent') ==> ('vegetables',) , 0.844
# Rule: ('yogurt', 'individual meals') ==> ('vegetables',) , 0.844
# Rule: ('yogurt', 'poultry') ==> ('vegetables',) , 0.845
# Rule: ('ketchup', 'sandwich loaves') ==> ('vegetables',) , 0.845
# Rule: ('sandwich bags', 'lunch meat') ==> ('vegetables',) , 0.845
# Rule: ('aluminum foil', 'poultry') ==> ('vegetables',) , 0.845
# Rule: ('soda', 'eggs') ==> ('vegetables',) , 0.845
# Rule: ('aluminum foil', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.845
# Rule: ('pasta', 'laundry detergent') ==> ('vegetables',) , 0.846
# Rule: ('pasta', 'spaghetti sauce') ==> ('vegetables',) , 0.846
# Rule: ('poultry', 'spaghetti sauce') ==> ('vegetables',) , 0.846
# Rule: ('ketchup', 'eggs') ==> ('vegetables',) , 0.847
# Rule: ('paper towels', 'soap') ==> ('vegetables',) , 0.847
# Rule: ('laundry detergent', 'soap') ==> ('vegetables',) , 0.847
# Rule: ('aluminum foil', 'mixes') ==> ('vegetables',) , 0.847
# Rule: ('dinner rolls', 'paper towels') ==> ('vegetables',) , 0.847
# Rule: ('dinner rolls', 'bagels') ==> ('vegetables',) , 0.847
# Rule: ('sugar', 'poultry') ==> ('vegetables',) , 0.848
# Rule: ('bagels', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.848
# Rule: ('paper towels', 'all- purpose') ==> ('vegetables',) , 0.848
# Rule: ('eggs', 'pork') ==> ('vegetables',) , 0.849
# Rule: ('shampoo', 'eggs') ==> ('vegetables',) , 0.849
# Rule: ('lunch meat', 'poultry') ==> ('vegetables',) , 0.849
# Rule: ('spaghetti sauce', 'eggs') ==> ('vegetables',) , 0.849
# Rule: ('sandwich bags', 'cheeses') ==> ('vegetables',) , 0.850
# Rule: ('pasta', 'eggs') ==> ('vegetables',) , 0.850
# Rule: ('sandwich loaves', 'ice cream') ==> ('vegetables',) , 0.850
# Rule: ('yogurt', 'pasta') ==> ('vegetables',) , 0.851
# Rule: ('sandwich loaves', 'mixes') ==> ('vegetables',) , 0.851
# Rule: ('butter', 'juice') ==> ('vegetables',) , 0.851
# Rule: ('soda', 'lunch meat') ==> ('vegetables',) , 0.852
# Rule: ('sugar', 'waffles') ==> ('vegetables',) , 0.852
# Rule: ('yogurt', 'dinner rolls') ==> ('vegetables',) , 0.852
# Rule: ('laundry detergent', 'fruits') ==> ('vegetables',) , 0.852
# Rule: ('lunch meat', 'waffles') ==> ('vegetables',) , 0.852
# Rule: ('spaghetti sauce', 'soap') ==> ('vegetables',) , 0.852
# Rule: ('aluminum foil', 'lunch meat') ==> ('vegetables',) , 0.852
# Rule: ('yogurt', 'all- purpose') ==> ('vegetables',) , 0.853
# Rule: ('soda', 'shampoo') ==> ('vegetables',) , 0.854
# Rule: ('aluminum foil', 'sandwich loaves') ==> ('vegetables',) , 0.854
# Rule: ('dinner rolls', 'lunch meat') ==> ('vegetables',) , 0.854
# Rule: ('laundry detergent', 'poultry') ==> ('vegetables',) , 0.854
# Rule: ('dishwashing liquid/detergent', 'poultry') ==> ('vegetables',) , 0.854
# Rule: ('waffles', 'eggs') ==> ('vegetables',) , 0.855
# Rule: ('yogurt', 'ketchup') ==> ('vegetables',) , 0.856
# Rule: ('yogurt', 'tortillas') ==> ('vegetables',) , 0.856
# Rule: ('toilet paper', 'laundry detergent') ==> ('vegetables',) , 0.856
# Rule: ('butter', 'eggs') ==> ('vegetables',) , 0.856
# Rule: ('coffee/tea', 'eggs') ==> ('vegetables',) , 0.856
# Rule: ('dinner rolls', 'soda') ==> ('vegetables',) , 0.856
# Rule: ('yogurt', 'spaghetti sauce') ==> ('vegetables',) , 0.857
# Rule: ('yogurt', 'soda') ==> ('vegetables',) , 0.858
# Rule: ('laundry detergent', 'cheeses') ==> ('vegetables',) , 0.858
# Rule: ('yogurt', 'beef') ==> ('vegetables',) , 0.858
# Rule: ('soda', 'aluminum foil') ==> ('vegetables',) , 0.859
# Rule: ('milk', 'eggs') ==> ('vegetables',) , 0.859
# Rule: ('laundry detergent', 'waffles') ==> ('vegetables',) , 0.860
# Rule: ('dinner rolls', 'toilet paper') ==> ('vegetables',) , 0.860
# Rule: ('sandwich loaves', 'shampoo') ==> ('vegetables',) , 0.860
# Rule: ('mixes', 'poultry') ==> ('vegetables',) , 0.860
# Rule: ('beef', 'eggs') ==> ('vegetables',) , 0.860
# Rule: ('laundry detergent', 'sandwich bags') ==> ('vegetables',) , 0.860
# Rule: ('laundry detergent', 'eggs') ==> ('vegetables',) , 0.860
# Rule: ('yogurt', 'aluminum foil') ==> ('vegetables',) , 0.861
# Rule: ('laundry detergent', 'individual meals') ==> ('vegetables',) , 0.861
# Rule: ('paper towels', 'poultry') ==> ('vegetables',) , 0.862
# Rule: ('aluminum foil', 'shampoo') ==> ('vegetables',) , 0.862
# Rule: ('paper towels', 'eggs') ==> ('vegetables',) , 0.862
# Rule: ('laundry detergent', 'paper towels') ==> ('vegetables',) , 0.863
# Rule: ('yogurt', 'milk') ==> ('vegetables',) , 0.864
# Rule: ('bagels', 'eggs') ==> ('vegetables',) , 0.864
# Rule: ('cereals', 'eggs') ==> ('vegetables',) , 0.864
# Rule: ('dinner rolls', 'sandwich loaves') ==> ('vegetables',) , 0.865
# Rule: ('sandwich loaves', 'poultry') ==> ('vegetables',) , 0.866
# Rule: ('dinner rolls', 'laundry detergent') ==> ('vegetables',) , 0.867
# Rule: ('laundry detergent', 'ice cream') ==> ('vegetables',) , 0.867
# Rule: ('coffee/tea', 'sandwich loaves') ==> ('vegetables',) , 0.867
# Rule: ('ketchup', 'paper towels') ==> ('vegetables',) , 0.868
# Rule: ('shampoo', 'laundry detergent') ==> ('vegetables',) , 0.869
# Rule: ('yogurt', 'sandwich bags') ==> ('vegetables',) , 0.869
# Rule: ('aluminum foil', 'bagels') ==> ('vegetables',) , 0.870
# Rule: ('dinner rolls', 'waffles') ==> ('vegetables',) , 0.870
# Rule: ('sugar', 'eggs') ==> ('vegetables',) , 0.872
# Rule: ('juice', 'eggs') ==> ('vegetables',) , 0.872
# Rule: ('eggs', 'fruits') ==> ('vegetables',) , 0.873
# Rule: ('yogurt', 'sandwich loaves') ==> ('vegetables',) , 0.874
# Rule: ('soap', 'eggs') ==> ('vegetables',) , 0.874
# Rule: ('individual meals', 'eggs') ==> ('vegetables',) , 0.874
# Rule: ('yogurt', 'lunch meat') ==> ('vegetables',) , 0.874
# Rule: ('sugar', 'lunch meat') ==> ('vegetables',) , 0.875
# Rule: ('laundry detergent', 'juice') ==> ('vegetables',) , 0.876
# Rule: ('aluminum foil', 'eggs') ==> ('vegetables',) , 0.877
# Rule: ('sugar', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.879
# Rule: ('all- purpose', 'eggs') ==> ('vegetables',) , 0.879
# Rule: ('sandwich bags', 'eggs') ==> ('vegetables',) , 0.880
# Rule: ('poultry', 'eggs') ==> ('vegetables',) , 0.881
# Rule: ('sugar', 'aluminum foil') ==> ('vegetables',) , 0.883
# Rule: ('yogurt', 'laundry detergent') ==> ('vegetables',) , 0.883
# Rule: ('lunch meat', 'eggs') ==> ('vegetables',) , 0.884
# Rule: ('eggs', 'cheeses') ==> ('vegetables',) , 0.886
# Rule: ('yogurt', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.889
# Rule: ('yogurt', 'paper towels') ==> ('vegetables',) , 0.890
# Rule: ('cereals', 'laundry detergent') ==> ('vegetables',) , 0.891
# Rule: ('dishwashing liquid/detergent', 'eggs') ==> ('vegetables',) , 0.897
# Rule: ('dinner rolls', 'eggs') ==> ('vegetables',) , 0.899
# Rule: ('yogurt', 'eggs') ==> ('vegetables',) , 0.899

# %%
print ('# # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #') 
print ('Case 2 (minimum support=0.15 and minimum confidence=0.6)') 
print ('Case 2 Reasoning:We eliminate a number of redundant values and most of the results obtained are unique')
print ('Case 2 Output:') 
# %run apriori.py -f dataset.csv -s 0.15 -c 0.65
# Out:
# # # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #
# Case 2 (minimum support=0.15 and minimum confidence=0.6)
# Case 2 Reasoning:We eliminate a number of redundant values and most of the results obtained are unique
# Case 2 Output:
#
# ------------ITEMS-----------------
# item: ('juice', 'cheeses') , 0.150
# item: ('soda', 'fruits') , 0.150
# item: ('dinner rolls', 'toilet paper') , 0.150
# item: ('cereals', 'pork') , 0.150
# item: ('sandwich loaves', 'spaghetti sauce') , 0.150
# item: ('butter', 'cereals') , 0.150
# item: ('all- purpose', 'fruits') , 0.150
# item: ('soda', 'shampoo') , 0.150
# item: ('shampoo', 'ice cream') , 0.150
# item: ('paper towels', 'sandwich bags') , 0.150
# item: ('beef', 'pork') , 0.150
# item: ('cheeses', 'pork') , 0.150
# item: ('flour', 'mixes') , 0.150
# item: ('soda', 'mixes') , 0.150
# item: ('shampoo', 'sandwich loaves') , 0.150
# item: ('bagels', 'all- purpose') , 0.150
# item: ('butter', 'spaghetti sauce') , 0.150
# item: ('paper towels', 'fruits') , 0.150
# item: ('aluminum foil', 'sandwich loaves') , 0.150
# item: ('sandwich bags', 'pork') , 0.150
# item: ('vegetables', 'eggs', 'cheeses') , 0.150
# item: ('sugar', 'bagels') , 0.151
# item: ('sugar', 'eggs') , 0.151
# item: ('pasta', 'milk') , 0.151
# item: ('shampoo', 'soap') , 0.151
# item: ('sugar', 'pasta') , 0.151
# item: ('eggs', 'pork') , 0.151
# item: ('aluminum foil', 'sandwich bags') , 0.151
# item: ('paper towels', 'cheeses') , 0.151
# item: ('flour', 'soap') , 0.151
# item: ('yogurt', 'pork') , 0.151
# item: ('cereals', 'all- purpose') , 0.151
# item: ('shampoo', 'pasta') , 0.151
# item: ('ketchup', 'shampoo') , 0.151
# item: ('shampoo', 'eggs') , 0.151
# item: ('cereals', 'vegetables', 'eggs') , 0.151
# item: ('cereals', 'laundry detergent', 'vegetables') , 0.151
# item: ('pasta', 'bagels') , 0.152
# item: ('shampoo', 'individual meals') , 0.152
# item: ('milk', 'all- purpose') , 0.152
# item: ('waffles', 'pork') , 0.152
# item: ('eggs', 'fruits') , 0.152
# item: ('butter', 'bagels') , 0.152
# item: ('tortillas', 'milk') , 0.152
# item: ('shampoo', 'all- purpose') , 0.152
# item: ('tortillas', 'dishwashing liquid/detergent') , 0.152
# item: ('coffee/tea', 'flour') , 0.152
# item: ('toilet paper', 'spaghetti sauce') , 0.152
# item: ('coffee/tea', 'milk') , 0.152
# item: ('hand soap', 'mixes') , 0.152
# item: ('mixes', 'all- purpose') , 0.152
# item: ('flour', 'dishwashing liquid/detergent') , 0.152
# item: ('butter', 'waffles') , 0.152
# item: ('sugar', 'dishwashing liquid/detergent') , 0.152
# item: ('sugar', 'toilet paper') , 0.152
# item: ('coffee/tea', 'bagels') , 0.152
# item: ('yogurt', 'paper towels') , 0.152
# item: ('laundry detergent', 'individual meals') , 0.152
# item: ('dinner rolls', 'butter') , 0.152
# item: ('sugar', 'vegetables', 'poultry') , 0.152
# item: ('yogurt', 'vegetables', 'aluminum foil') , 0.152
# item: ('coffee/tea', 'sandwich bags') , 0.153
# item: ('yogurt', 'tortillas') , 0.153
# item: ('yogurt', 'sandwich loaves') , 0.153
# item: ('sandwich bags', 'lunch meat') , 0.153
# item: ('ketchup', 'sandwich loaves') , 0.153
# item: ('butter', 'mixes') , 0.153
# item: ('yogurt', 'ketchup') , 0.153
# item: ('ketchup', 'paper towels') , 0.153
# item: ('pasta', 'tortillas') , 0.153
# item: ('laundry detergent', 'bagels') , 0.153
# item: ('toilet paper', 'dishwashing liquid/detergent') , 0.153
# item: ('coffee/tea', 'shampoo') , 0.153
# item: ('toilet paper', 'laundry detergent') , 0.153
# item: ('coffee/tea', 'individual meals') , 0.153
# item: ('tortillas', 'individual meals') , 0.153
# item: ('juice', 'dishwashing liquid/detergent') , 0.153
# item: ('toilet paper', 'individual meals') , 0.153
# item: ('sugar', 'cheeses') , 0.153
# item: ('dinner rolls', 'sandwich bags') , 0.153
# item: ('dishwashing liquid/detergent', 'pork') , 0.153
# item: ('yogurt', 'vegetables', 'poultry') , 0.153
# item: ('ketchup', 'pork') , 0.154
# item: ('milk', 'juice') , 0.154
# item: ('sandwich bags', 'dishwashing liquid/detergent') , 0.154
# item: ('butter', 'ice cream') , 0.154
# item: ('paper towels', 'bagels') , 0.154
# item: ('pasta', 'laundry detergent') , 0.154
# item: ('all- purpose', 'pork') , 0.154
# item: ('dinner rolls', 'hand soap') , 0.154
# item: ('ice cream', 'mixes') , 0.154
# item: ('coffee/tea', 'dishwashing liquid/detergent') , 0.154
# item: ('juice', 'all- purpose') , 0.154
# item: ('toilet paper', 'all- purpose') , 0.154
# item: ('coffee/tea', 'paper towels') , 0.154
# item: ('shampoo', 'beef') , 0.154
# item: ('butter', 'sandwich bags') , 0.154
# item: ('individual meals', 'eggs') , 0.154
# item: ('shampoo', 'laundry detergent') , 0.154
# item: ('lunch meat', 'mixes') , 0.154
# item: ('sandwich bags', 'fruits') , 0.154
# item: ('vegetables', 'dishwashing liquid/detergent', 'eggs') , 0.154
# item: ('laundry detergent', 'soap') , 0.155
# item: ('paper towels', 'soap') , 0.155
# item: ('dinner rolls', 'flour') , 0.155
# item: ('paper towels', 'individual meals') , 0.155
# item: ('mixes', 'waffles') , 0.155
# item: ('coffee/tea', 'tortillas') , 0.155
# item: ('bagels', 'sandwich bags') , 0.155
# item: ('soda', 'butter') , 0.155
# item: ('ketchup', 'spaghetti sauce') , 0.155
# item: ('aluminum foil', 'flour') , 0.155
# item: ('hand soap', 'poultry') , 0.155
# item: ('butter', 'toilet paper') , 0.155
# item: ('ketchup', 'all- purpose') , 0.155
# item: ('dinner rolls', 'beef') , 0.155
# item: ('yogurt', 'sandwich bags') , 0.155
# item: ('sugar', 'soap') , 0.155
# item: ('mixes', 'pork') , 0.155
# item: ('individual meals', 'juice') , 0.155
# item: ('dinner rolls', 'bagels') , 0.155
# item: ('shampoo', 'waffles') , 0.155
# item: ('bagels', 'pork') , 0.155
# item: ('paper towels', 'beef') , 0.155
# item: ('dinner rolls', 'all- purpose') , 0.155
# item: ('ketchup', 'dishwashing liquid/detergent') , 0.155
# item: ('coffee/tea', 'pasta') , 0.155
# item: ('laundry detergent', 'juice') , 0.155
# item: ('soda', 'tortillas') , 0.155
# item: ('beef', 'juice') , 0.155
# item: ('sandwich bags', 'mixes') , 0.155
# item: ('sandwich loaves', 'cheeses') , 0.155
# item: ('spaghetti sauce', 'fruits') , 0.155
# item: ('ketchup', 'beef') , 0.155
# item: ('shampoo', 'paper towels') , 0.155
# item: ('sugar', 'beef') , 0.155
# item: ('yogurt', 'ice cream') , 0.155
# item: ('soda', 'beef') , 0.155
# item: ('dinner rolls', 'paper towels') , 0.155
# item: ('vegetables', 'poultry', 'eggs') , 0.155
# item: ('cereals', 'juice') , 0.156
# item: ('ketchup', 'ice cream') , 0.156
# item: ('dinner rolls', 'soap') , 0.156
# item: ('shampoo', 'mixes') , 0.156
# item: ('ketchup', 'milk') , 0.156
# item: ('soda', 'cereals') , 0.156
# item: ('ketchup', 'pasta') , 0.156
# item: ('beef', 'sandwich bags') , 0.156
# item: ('juice', 'soap') , 0.156
# item: ('paper towels', 'all- purpose') , 0.156
# item: ('coffee/tea', 'toilet paper') , 0.156
# item: ('coffee/tea', 'juice') , 0.156
# item: ('yogurt', 'flour') , 0.156
# item: ('sugar', 'cereals') , 0.156
# item: ('juice', 'pork') , 0.156
# item: ('aluminum foil', 'spaghetti sauce') , 0.156
# item: ('milk', 'cheeses') , 0.156
# item: ('individual meals', 'waffles') , 0.156
# item: ('dinner rolls', 'milk') , 0.156
# item: ('ketchup', 'toilet paper') , 0.156
# item: ('paper towels', 'spaghetti sauce') , 0.156
# item: ('ice cream', 'sandwich bags') , 0.156
# item: ('laundry detergent', 'waffles') , 0.156
# item: ('beef', 'bagels') , 0.156
# item: ('toilet paper', 'tortillas') , 0.156
# item: ('paper towels', 'waffles') , 0.156
# item: ('flour', 'lunch meat') , 0.156
# item: ('vegetables', 'mixes', 'poultry') , 0.156
# item: ('dinner rolls', 'vegetables', 'eggs') , 0.156
# item: ('aluminum foil', 'all- purpose') , 0.157
# item: ('aluminum foil', 'soap') , 0.157
# item: ('aluminum foil', 'pasta') , 0.157
# item: ('ketchup', 'laundry detergent') , 0.157
# item: ('ice cream', 'all- purpose') , 0.157
# item: ('sugar', 'ice cream') , 0.157
# item: ('laundry detergent', 'lunch meat') , 0.157
# item: ('soda', 'bagels') , 0.157
# item: ('toilet paper', 'shampoo') , 0.157
# item: ('toilet paper', 'beef') , 0.157
# item: ('beef', 'dishwashing liquid/detergent') , 0.157
# item: ('flour', 'poultry') , 0.157
# item: ('dinner rolls', 'juice') , 0.157
# item: ('beef', 'waffles') , 0.157
# item: ('aluminum foil', 'eggs') , 0.157
# item: ('soda', 'juice') , 0.157
# item: ('vegetables', 'lunch meat', 'waffles') , 0.157
# item: ('yogurt', 'vegetables', 'eggs') , 0.157
# item: ('aluminum foil', 'ketchup') , 0.158
# item: ('dinner rolls', 'tortillas') , 0.158
# item: ('cereals', 'sandwich bags') , 0.158
# item: ('aluminum foil', 'fruits') , 0.158
# item: ('butter', 'laundry detergent') , 0.158
# item: ('milk', 'sandwich bags') , 0.158
# item: ('beef', 'lunch meat') , 0.158
# item: ('sandwich loaves', 'soap') , 0.158
# item: ('soda', 'flour') , 0.158
# item: ('yogurt', 'laundry detergent') , 0.158
# item: ('sandwich loaves', 'ice cream') , 0.158
# item: ('individual meals', 'spaghetti sauce') , 0.158
# item: ('milk', 'spaghetti sauce') , 0.158
# item: ('bagels', 'lunch meat') , 0.158
# item: ('shampoo', 'bagels') , 0.158
# item: ('mixes', 'spaghetti sauce') , 0.158
# item: ('yogurt', 'individual meals') , 0.158
# item: ('dinner rolls', 'ketchup') , 0.158
# item: ('beef', 'spaghetti sauce') , 0.158
# item: ('shampoo', 'cheeses') , 0.158
# item: ('yogurt', 'fruits') , 0.158
# item: ('yogurt', 'dishwashing liquid/detergent') , 0.158
# item: ('yogurt', 'shampoo') , 0.158
# item: ('soda', 'ketchup') , 0.158
# item: ('ketchup', 'bagels') , 0.158
# item: ('paper towels', 'mixes') , 0.158
# item: ('vegetables', 'lunch meat', 'poultry') , 0.158
# item: ('soda', 'vegetables', 'eggs') , 0.158
# item: ('yogurt', 'pasta') , 0.159
# item: ('aluminum foil', 'dishwashing liquid/detergent') , 0.159
# item: ('coffee/tea', 'eggs') , 0.159
# item: ('laundry detergent', 'ice cream') , 0.159
# item: ('mixes', 'eggs') , 0.159
# item: ('butter', 'eggs') , 0.159
# item: ('soda', 'coffee/tea') , 0.159
# item: ('shampoo', 'cereals') , 0.159
# item: ('aluminum foil', 'coffee/tea') , 0.159
# item: ('milk', 'mixes') , 0.159
# item: ('sugar', 'yogurt') , 0.159
# item: ('sandwich bags', 'soap') , 0.159
# item: ('paper towels', 'poultry') , 0.159
# item: ('paper towels', 'juice') , 0.159
# item: ('paper towels', 'dishwashing liquid/detergent') , 0.159
# item: ('ice cream', 'spaghetti sauce') , 0.159
# item: ('cereals', 'tortillas') , 0.159
# item: ('sandwich bags', 'waffles') , 0.159
# item: ('tortillas', 'eggs') , 0.159
# item: ('lunch meat', 'eggs') , 0.159
# item: ('coffee/tea', 'soap') , 0.159
# item: ('individual meals', 'dishwashing liquid/detergent') , 0.159
# item: ('aluminum foil', 'shampoo') , 0.159
# item: ('dinner rolls', 'coffee/tea') , 0.159
# item: ('shampoo', 'lunch meat') , 0.160
# item: ('sandwich loaves', 'individual meals') , 0.160
# item: ('pasta', 'soap') , 0.160
# item: ('butter', 'lunch meat') , 0.160
# item: ('soap', 'dishwashing liquid/detergent') , 0.160
# item: ('all- purpose', 'eggs') , 0.160
# item: ('aluminum foil', 'beef') , 0.160
# item: ('sugar', 'waffles') , 0.160
# item: ('pasta', 'all- purpose') , 0.160
# item: ('beef', 'cheeses') , 0.160
# item: ('beef', 'soap') , 0.160
# item: ('individual meals', 'soap') , 0.160
# item: ('aluminum foil', 'paper towels') , 0.160
# item: ('pasta', 'spaghetti sauce') , 0.160
# item: ('pasta', 'cheeses') , 0.160
# item: ('soda', 'lunch meat') , 0.160
# item: ('butter', 'cheeses') , 0.160
# item: ('bagels', 'waffles') , 0.160
# item: ('toilet paper', 'ice cream') , 0.160
# item: ('ice cream', 'bagels') , 0.160
# item: ('cereals', 'individual meals') , 0.160
# item: ('aluminum foil', 'toilet paper') , 0.160
# item: ('lunch meat', 'all- purpose') , 0.160
# item: ('laundry detergent', 'mixes') , 0.160
# item: ('flour', 'cheeses') , 0.160
# item: ('yogurt', 'spaghetti sauce') , 0.160
# item: ('vegetables', 'poultry', 'dishwashing liquid/detergent') , 0.160
# item: ('aluminum foil', 'laundry detergent') , 0.161
# item: ('ketchup', 'juice') , 0.161
# item: ('aluminum foil', 'lunch meat') , 0.161
# item: ('milk', 'lunch meat') , 0.161
# item: ('aluminum foil', 'milk') , 0.161
# item: ('soda', 'paper towels') , 0.161
# item: ('laundry detergent', 'cheeses') , 0.161
# item: ('ketchup', 'cheeses') , 0.161
# item: ('yogurt', 'lunch meat') , 0.161
# item: ('tortillas', 'sandwich bags') , 0.161
# item: ('lunch meat', 'cheeses') , 0.161
# item: ('milk', 'beef') , 0.161
# item: ('yogurt', 'coffee/tea') , 0.161
# item: ('soap', 'spaghetti sauce') , 0.161
# item: ('yogurt', 'beef') , 0.161
# item: ('dishwashing liquid/detergent', 'all- purpose') , 0.161
# item: ('cereals', 'waffles') , 0.161
# item: ('individual meals', 'cheeses') , 0.161
# item: ('milk', 'bagels') , 0.162
# item: ('cereals', 'fruits') , 0.162
# item: ('ketchup', 'waffles') , 0.162
# item: ('pasta', 'poultry') , 0.162
# item: ('pasta', 'dishwashing liquid/detergent') , 0.162
# item: ('pasta', 'cereals') , 0.162
# item: ('pasta', 'waffles') , 0.162
# item: ('toilet paper', 'paper towels') , 0.162
# item: ('laundry detergent', 'spaghetti sauce') , 0.162
# item: ('lunch meat', 'juice') , 0.162
# item: ('soda', 'aluminum foil') , 0.162
# item: ('ice cream', 'beef') , 0.162
# item: ('milk', 'paper towels') , 0.162
# item: ('sugar', 'lunch meat') , 0.162
# item: ('milk', 'soap') , 0.162
# item: ('dinner rolls', 'ice cream') , 0.162
# item: ('dinner rolls', 'vegetables', 'poultry') , 0.162
# item: ('yogurt', 'toilet paper') , 0.162
# item: ('yogurt', 'bagels') , 0.162
# item: ('bagels', 'juice') , 0.162
# item: ('ice cream', 'individual meals') , 0.162
# item: ('cereals', 'bagels') , 0.162
# item: ('dinner rolls', 'lunch meat') , 0.162
# item: ('soda', 'sandwich bags') , 0.162
# item: ('tortillas', 'mixes') , 0.162
# item: ('soda', 'toilet paper') , 0.162
# item: ('soap', 'cheeses') , 0.162
# item: ('cereals', 'soap') , 0.162
# item: ('aluminum foil', 'individual meals') , 0.162
# item: ('soda', 'sugar') , 0.162
# item: ('tortillas', 'bagels') , 0.162
# item: ('dinner rolls', 'mixes') , 0.162
# item: ('laundry detergent', 'all- purpose') , 0.162
# item: ('lunch meat', 'fruits') , 0.163
# item: ('spaghetti sauce', 'eggs') , 0.163
# item: ('laundry detergent', 'dishwashing liquid/detergent') , 0.163
# item: ('sandwich loaves', 'poultry') , 0.163
# item: ('toilet paper', 'eggs') , 0.163
# item: ('waffles', 'fruits') , 0.163
# item: ('toilet paper', 'bagels') , 0.163
# item: ('beef', 'eggs') , 0.163
# item: ('laundry detergent', 'sandwich bags') , 0.163
# item: ('soda', 'laundry detergent') , 0.163
# item: ('soap', 'all- purpose') , 0.163
# item: ('tortillas', 'lunch meat') , 0.163
# item: ('cheeses', 'fruits') , 0.163
# item: ('laundry detergent', 'eggs') , 0.163
# item: ('dishwashing liquid/detergent', 'cheeses') , 0.163
# item: ('toilet paper', 'milk') , 0.163
# item: ('mixes', 'cheeses') , 0.163
# item: ('yogurt', 'mixes') , 0.164
# item: ('toilet paper', 'soap') , 0.164
# item: ('poultry', 'pork') , 0.164
# item: ('ketchup', 'soap') , 0.164
# item: ('dinner rolls', 'sugar') , 0.164
# item: ('ketchup', 'sandwich bags') , 0.164
# item: ('bagels', 'mixes') , 0.164
# item: ('coffee/tea', 'ketchup') , 0.164
# item: ('toilet paper', 'lunch meat') , 0.164
# item: ('cereals', 'paper towels') , 0.164
# item: ('waffles', 'spaghetti sauce') , 0.164
# item: ('pasta', 'paper towels') , 0.164
# item: ('milk', 'ice cream') , 0.165
# item: ('ice cream', 'dishwashing liquid/detergent') , 0.165
# item: ('ice cream', 'fruits') , 0.165
# item: ('ketchup', 'poultry') , 0.165
# item: ('paper towels', 'lunch meat') , 0.165
# item: ('spaghetti sauce', 'cheeses') , 0.165
# item: ('ketchup', 'mixes') , 0.165
# item: ('dinner rolls', 'laundry detergent') , 0.165
# item: ('juice', 'eggs') , 0.165
# item: ('individual meals', 'bagels') , 0.165
# item: ('dinner rolls', 'dishwashing liquid/detergent') , 0.165
# item: ('coffee/tea', 'ice cream') , 0.165
# item: ('aluminum foil', 'cereals') , 0.166
# item: ('lunch meat', 'soap') , 0.166
# item: ('milk', 'laundry detergent') , 0.166
# item: ('cereals', 'ice cream') , 0.166
# item: ('dinner rolls', 'aluminum foil') , 0.166
# item: ('paper towels', 'eggs') , 0.166
# item: ('ketchup', 'eggs') , 0.166
# item: ('beef', 'fruits') , 0.166
# item: ('butter', 'poultry') , 0.166
# item: ('dinner rolls', 'yogurt') , 0.166
# item: ('soda', 'individual meals') , 0.166
# item: ('toilet paper', 'cereals') , 0.166
# item: ('soap', 'eggs') , 0.167
# item: ('ice cream', 'soap') , 0.167
# item: ('cereals', 'spaghetti sauce') , 0.167
# item: ('ice cream', 'eggs') , 0.167
# item: ('coffee/tea', 'lunch meat') , 0.167
# item: ('ice cream', 'juice') , 0.167
# item: ('soda', 'yogurt') , 0.167
# item: ('soda', 'dishwashing liquid/detergent') , 0.167
# item: ('bagels', 'spaghetti sauce') , 0.167
# item: ('waffles', 'poultry') , 0.167
# item: ('waffles', 'juice') , 0.167
# item: ('yogurt', 'all- purpose') , 0.167
# item: ('pasta', 'ice cream') , 0.168
# item: ('coffee/tea', 'cheeses') , 0.168
# item: ('poultry', 'fruits') , 0.168
# item: ('bagels', 'cheeses') , 0.168
# item: ('soda', 'spaghetti sauce') , 0.168
# item: ('bagels', 'eggs') , 0.168
# item: ('dinner rolls', 'cheeses') , 0.168
# item: ('bagels', 'fruits') , 0.168
# item: ('bagels', 'poultry') , 0.168
# item: ('yogurt', 'milk') , 0.168
# item: ('bagels', 'dishwashing liquid/detergent') , 0.168
# item: ('waffles', 'all- purpose') , 0.168
# item: ('dishwashing liquid/detergent', 'fruits') , 0.168
# item: ('toilet paper', 'cheeses') , 0.168
# item: ('cereals', 'lunch meat') , 0.169
# item: ('soda', 'cheeses') , 0.169
# item: ('milk', 'eggs') , 0.169
# item: ('lunch meat', 'spaghetti sauce') , 0.169
# item: ('cereals', 'beef') , 0.169
# item: ('aluminum foil', 'bagels') , 0.169
# item: ('soda', 'ice cream') , 0.169
# item: ('cereals', 'laundry detergent') , 0.169
# item: ('dinner rolls', 'waffles') , 0.169
# item: ('soda', 'pasta') , 0.169
# item: ('coffee/tea', 'cereals') , 0.169
# item: ('sandwich bags', 'cheeses') , 0.169
# item: ('dinner rolls', 'shampoo') , 0.169
# item: ('aluminum foil', 'cheeses') , 0.169
# item: ('waffles', 'eggs') , 0.169
# item: ('pasta', 'eggs') , 0.169
# item: ('cereals', 'dishwashing liquid/detergent') , 0.169
# item: ('aluminum foil', 'waffles') , 0.169
# item: ('eggs', 'cheeses') , 0.169
# item: ('shampoo', 'juice') , 0.170
# item: ('beef', 'poultry') , 0.170
# item: ('milk', 'dishwashing liquid/detergent') , 0.170
# item: ('individual meals', 'poultry') , 0.170
# item: ('ice cream', 'paper towels') , 0.170
# item: ('dinner rolls', 'cereals') , 0.171
# item: ('shampoo', 'poultry') , 0.171
# item: ('dinner rolls', 'soda') , 0.171
# item: ('spaghetti sauce', 'poultry') , 0.171
# item: ('tortillas', 'poultry') , 0.171
# item: ('toilet paper', 'poultry') , 0.171
# item: ('dishwashing liquid/detergent', 'eggs') , 0.171
# item: ('dinner rolls', 'spaghetti sauce') , 0.172
# item: ('coffee/tea', 'waffles') , 0.172
# item: ('yogurt', 'cereals') , 0.172
# item: ('sandwich bags', 'poultry') , 0.172
# item: ('yogurt', 'cheeses') , 0.172
# item: ('juice', 'spaghetti sauce') , 0.172
# item: ('aluminum foil', 'juice') , 0.172
# item: ('toilet paper', 'juice') , 0.172
# item: ('aluminum foil', 'mixes') , 0.172
# item: ('waffles', 'cheeses') , 0.173
# item: ('ice cream', 'waffles') , 0.173
# item: ('dinner rolls', 'pasta') , 0.173
# item: ('soda', 'poultry') , 0.173
# item: ('waffles', 'soap') , 0.173
# item: ('soda', 'milk') , 0.173
# item: ('toilet paper', 'waffles') , 0.173
# item: ('cereals', 'mixes') , 0.174
# item: ('dinner rolls', 'eggs') , 0.174
# item: ('yogurt', 'waffles') , 0.174
# item: ('cereals', 'milk') , 0.174
# item: ('ice cream', 'lunch meat') , 0.174
# item: ('lunch meat', 'dishwashing liquid/detergent') , 0.174
# item: ('soda', 'soap') , 0.175
# item: ('laundry detergent', 'poultry') , 0.175
# item: ('coffee/tea', 'poultry') , 0.175
# item: ('cereals', 'cheeses') , 0.175
# item: ('cereals', 'eggs') , 0.175
# item: ('yogurt', 'eggs') , 0.175
# item: ('poultry', 'all- purpose') , 0.176
# item: ('aluminum foil', 'poultry') , 0.176
# item: ('waffles', 'dishwashing liquid/detergent') , 0.176
# item: ('aluminum foil', 'ice cream') , 0.176
# item: ('yogurt', 'juice') , 0.176
# item: ('aluminum foil', 'yogurt') , 0.176
# item: ('juice', 'poultry') , 0.176
# item: ('poultry', 'eggs') , 0.176
# item: ('soda', 'waffles') , 0.177
# item: ('individual meals', 'lunch meat') , 0.177
# item: ('milk', 'poultry') , 0.178
# item: ('ice cream', 'poultry') , 0.179
# item: ('sugar', 'poultry') , 0.179
# item: ('ice cream', 'cheeses') , 0.179
# item: ('mixes', 'dishwashing liquid/detergent') , 0.180
# item: ('yogurt', 'poultry') , 0.181
# item: ('poultry', 'cheeses') , 0.181
# item: ('cereals', 'poultry') , 0.181
# item: ('mixes', 'poultry') , 0.182
# item: ('soap', 'poultry') , 0.183
# item: ('lunch meat', 'waffles') , 0.184
# item: ('lunch meat', 'poultry') , 0.186
# item: ('soda', 'eggs') , 0.187
# item: ('poultry', 'dishwashing liquid/detergent') , 0.187
# item: ('dinner rolls', 'poultry') , 0.195
# item: ('vegetables', 'pork') , 0.270
# item: ('hand soap', 'vegetables') , 0.270
# item: ('flour', 'vegetables') , 0.277
# item: ('sandwich loaves', 'vegetables') , 0.283
# item: ('butter', 'vegetables') , 0.284
# item: ('tortillas', 'vegetables') , 0.284
# item: ('vegetables', 'individual meals') , 0.285
# item: ('pasta', 'vegetables') , 0.286
# item: ('shampoo', 'vegetables') , 0.288
# item: ('toilet paper', 'vegetables') , 0.290
# item: ('coffee/tea', 'vegetables') , 0.290
# item: ('paper towels', 'vegetables') , 0.290
# item: ('vegetables', 'all- purpose') , 0.290
# item: ('vegetables', 'fruits') , 0.291
# item: ('vegetables', 'beef') , 0.291
# item: ('ketchup', 'vegetables') , 0.291
# item: ('vegetables', 'sandwich bags') , 0.293
# item: ('vegetables', 'juice') , 0.294
# item: ('vegetables', 'soap') , 0.295
# item: ('vegetables', 'mixes') , 0.296
# item: ('milk', 'vegetables') , 0.296
# item: ('vegetables', 'spaghetti sauce') , 0.297
# item: ('sugar', 'vegetables') , 0.298
# item: ('vegetables', 'bagels') , 0.300
# item: ('ice cream', 'vegetables') , 0.303
# item: ('soda', 'vegetables') , 0.306
# item: ('vegetables', 'dishwashing liquid/detergent') , 0.306
# item: ('dinner rolls', 'vegetables') , 0.308
# item: ('laundry detergent', 'vegetables') , 0.309
# item: ('vegetables', 'cheeses') , 0.309
# item: ('cereals', 'vegetables') , 0.311
# item: ('aluminum foil', 'vegetables') , 0.311
# item: ('vegetables', 'lunch meat') , 0.312
# item: ('vegetables', 'waffles') , 0.315
# item: ('yogurt', 'vegetables') , 0.319
# item: ('vegetables', 'eggs') , 0.327
# item: ('vegetables', 'poultry') , 0.332
# item: ('hand soap',) , 0.346
# item: ('sandwich loaves',) , 0.349
# item: ('flour',) , 0.353
# item: ('pork',) , 0.356
# item: ('sugar',) , 0.361
# item: ('paper towels',) , 0.363
# item: ('butter',) , 0.368
# item: ('sandwich bags',) , 0.368
# item: ('shampoo',) , 0.369
# item: ('tortillas',) , 0.370
# item: ('fruits',) , 0.371
# item: ('pasta',) , 0.371
# item: ('ketchup',) , 0.371
# item: ('spaghetti sauce',) , 0.373
# item: ('beef',) , 0.375
# item: ('all- purpose',) , 0.375
# item: ('individual meals',) , 0.376
# item: ('mixes',) , 0.376
# item: ('juice',) , 0.377
# item: ('toilet paper',) , 0.378
# item: ('laundry detergent',) , 0.378
# item: ('coffee/tea',) , 0.379
# item: ('soap',) , 0.379
# item: ('milk',) , 0.380
# item: ('yogurt',) , 0.384
# item: ('aluminum foil',) , 0.385
# item: ('bagels',) , 0.385
# item: ('dishwashing liquid/detergent',) , 0.388
# item: ('dinner rolls',) , 0.389
# item: ('eggs',) , 0.390
# item: ('cheeses',) , 0.391
# item: ('soda',) , 0.391
# item: ('waffles',) , 0.394
# item: ('lunch meat',) , 0.395
# item: ('cereals',) , 0.396
# item: ('ice cream',) , 0.399
# item: ('poultry',) , 0.421
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------
# Rule: ('individual meals',) ==> ('vegetables',) , 0.759
# Rule: ('ice cream',) ==> ('vegetables',) , 0.760
# Rule: ('pork',) ==> ('vegetables',) , 0.760
# Rule: ('coffee/tea',) ==> ('vegetables',) , 0.764
# Rule: ('toilet paper',) ==> ('vegetables',) , 0.766
# Rule: ('tortillas',) ==> ('vegetables',) , 0.767
# Rule: ('pasta',) ==> ('vegetables',) , 0.771
# Rule: ('butter',) ==> ('vegetables',) , 0.771
# Rule: ('all- purpose',) ==> ('vegetables',) , 0.773
# Rule: ('beef',) ==> ('vegetables',) , 0.778
# Rule: ('soap',) ==> ('vegetables',) , 0.778
# Rule: ('milk',) ==> ('vegetables',) , 0.778
# Rule: ('bagels',) ==> ('vegetables',) , 0.779
# Rule: ('juice',) ==> ('vegetables',) , 0.781
# Rule: ('shampoo',) ==> ('vegetables',) , 0.781
# Rule: ('hand soap',) ==> ('vegetables',) , 0.782
# Rule: ('soda',) ==> ('vegetables',) , 0.782
# Rule: ('flour',) ==> ('vegetables',) , 0.784
# Rule: ('fruits',) ==> ('vegetables',) , 0.784
# Rule: ('ketchup',) ==> ('vegetables',) , 0.785
# Rule: ('cereals',) ==> ('vegetables',) , 0.785
# Rule: ('mixes',) ==> ('vegetables',) , 0.787
# Rule: ('poultry',) ==> ('vegetables',) , 0.787
# Rule: ('lunch meat',) ==> ('vegetables',) , 0.789
# Rule: ('dishwashing liquid/detergent',) ==> ('vegetables',) , 0.790
# Rule: ('cheeses',) ==> ('vegetables',) , 0.791
# Rule: ('dinner rolls',) ==> ('vegetables',) , 0.792
# Rule: ('spaghetti sauce',) ==> ('vegetables',) , 0.795
# Rule: ('sandwich bags',) ==> ('vegetables',) , 0.797
# Rule: ('paper towels',) ==> ('vegetables',) , 0.799
# Rule: ('waffles',) ==> ('vegetables',) , 0.800
# Rule: ('aluminum foil',) ==> ('vegetables',) , 0.808
# Rule: ('sandwich loaves',) ==> ('vegetables',) , 0.809
# Rule: ('laundry detergent',) ==> ('vegetables',) , 0.817
# Rule: ('sugar',) ==> ('vegetables',) , 0.825
# Rule: ('dinner rolls', 'poultry') ==> ('vegetables',) , 0.829
# Rule: ('yogurt',) ==> ('vegetables',) , 0.831
# Rule: ('eggs',) ==> ('vegetables',) , 0.838
# Rule: ('yogurt', 'poultry') ==> ('vegetables',) , 0.845
# Rule: ('soda', 'eggs') ==> ('vegetables',) , 0.845
# Rule: ('sugar', 'poultry') ==> ('vegetables',) , 0.848
# Rule: ('lunch meat', 'poultry') ==> ('vegetables',) , 0.849
# Rule: ('lunch meat', 'waffles') ==> ('vegetables',) , 0.852
# Rule: ('dishwashing liquid/detergent', 'poultry') ==> ('vegetables',) , 0.854
# Rule: ('mixes', 'poultry') ==> ('vegetables',) , 0.860
# Rule: ('yogurt', 'aluminum foil') ==> ('vegetables',) , 0.861
# Rule: ('cereals', 'eggs') ==> ('vegetables',) , 0.864
# Rule: ('poultry', 'eggs') ==> ('vegetables',) , 0.881
# Rule: ('eggs', 'cheeses') ==> ('vegetables',) , 0.886
# Rule: ('cereals', 'laundry detergent') ==> ('vegetables',) , 0.891
# Rule: ('dishwashing liquid/detergent', 'eggs') ==> ('vegetables',) , 0.897
# Rule: ('dinner rolls', 'eggs') ==> ('vegetables',) , 0.899
# Rule: ('yogurt', 'eggs') ==> ('vegetables',) , 0.899

# %%
print ('# # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #') 
print ('Case 3 (minimum support=0.29 and minimum confidence=0.75)')
print ('Case 3 Reasoning: In this case, we obtain the outcome with most important data. Most of the irrelavant/redundant data is eliminated.')
print ('Case 3 Output:')
# %run apriori.py -f dataset.csv -s 0.29 -c 0.75
# Out:
# # # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #
# Case 3 (minimum support=0.29 and minimum confidence=0.75)
# Case 3 Reasoning: In this case, we obtain the outcome with most important data. Most of the irrelavant/redundant data is eliminated.
# Case 3 Output:
#
# ------------ITEMS-----------------
# item: ('vegetables', 'fruits') , 0.291
# item: ('ketchup', 'vegetables') , 0.291
# item: ('vegetables', 'beef') , 0.291
# item: ('vegetables', 'sandwich bags') , 0.293
# item: ('vegetables', 'juice') , 0.294
# item: ('vegetables', 'soap') , 0.295
# item: ('vegetables', 'mixes') , 0.296
# item: ('milk', 'vegetables') , 0.296
# item: ('vegetables', 'spaghetti sauce') , 0.297
# item: ('sugar', 'vegetables') , 0.298
# item: ('vegetables', 'bagels') , 0.300
# item: ('ice cream', 'vegetables') , 0.303
# item: ('soda', 'vegetables') , 0.306
# item: ('vegetables', 'dishwashing liquid/detergent') , 0.306
# item: ('dinner rolls', 'vegetables') , 0.308
# item: ('vegetables', 'cheeses') , 0.309
# item: ('laundry detergent', 'vegetables') , 0.309
# item: ('aluminum foil', 'vegetables') , 0.311
# item: ('cereals', 'vegetables') , 0.311
# item: ('vegetables', 'lunch meat') , 0.312
# item: ('vegetables', 'waffles') , 0.315
# item: ('yogurt', 'vegetables') , 0.319
# item: ('vegetables', 'eggs') , 0.327
# item: ('vegetables', 'poultry') , 0.332
# item: ('hand soap',) , 0.346
# item: ('sandwich loaves',) , 0.349
# item: ('flour',) , 0.353
# item: ('pork',) , 0.356
# item: ('sugar',) , 0.361
# item: ('paper towels',) , 0.363
# item: ('butter',) , 0.368
# item: ('sandwich bags',) , 0.368
# item: ('shampoo',) , 0.369
# item: ('tortillas',) , 0.370
# item: ('fruits',) , 0.371
# item: ('pasta',) , 0.371
# item: ('ketchup',) , 0.371
# item: ('spaghetti sauce',) , 0.373
# item: ('beef',) , 0.375
# item: ('all- purpose',) , 0.375
# item: ('individual meals',) , 0.376
# item: ('mixes',) , 0.376
# item: ('juice',) , 0.377
# item: ('toilet paper',) , 0.378
# item: ('laundry detergent',) , 0.378
# item: ('coffee/tea',) , 0.379
# item: ('soap',) , 0.379
# item: ('milk',) , 0.380
# item: ('yogurt',) , 0.384
# item: ('aluminum foil',) , 0.385
# item: ('bagels',) , 0.385
# item: ('dishwashing liquid/detergent',) , 0.388
# item: ('dinner rolls',) , 0.389
# item: ('eggs',) , 0.390
# item: ('cheeses',) , 0.391
# item: ('soda',) , 0.391
# item: ('waffles',) , 0.394
# item: ('lunch meat',) , 0.395
# item: ('cereals',) , 0.396
# item: ('ice cream',) , 0.399
# item: ('poultry',) , 0.421
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------
# Rule: ('ice cream',) ==> ('vegetables',) , 0.760
# Rule: ('beef',) ==> ('vegetables',) , 0.778
# Rule: ('soap',) ==> ('vegetables',) , 0.778
# Rule: ('milk',) ==> ('vegetables',) , 0.778
# Rule: ('bagels',) ==> ('vegetables',) , 0.779
# Rule: ('juice',) ==> ('vegetables',) , 0.781
# Rule: ('soda',) ==> ('vegetables',) , 0.782
# Rule: ('fruits',) ==> ('vegetables',) , 0.784
# Rule: ('ketchup',) ==> ('vegetables',) , 0.785
# Rule: ('cereals',) ==> ('vegetables',) , 0.785
# Rule: ('mixes',) ==> ('vegetables',) , 0.787
# Rule: ('poultry',) ==> ('vegetables',) , 0.787
# Rule: ('lunch meat',) ==> ('vegetables',) , 0.789
# Rule: ('dishwashing liquid/detergent',) ==> ('vegetables',) , 0.790
# Rule: ('cheeses',) ==> ('vegetables',) , 0.791
# Rule: ('dinner rolls',) ==> ('vegetables',) , 0.792
# Rule: ('spaghetti sauce',) ==> ('vegetables',) , 0.795
# Rule: ('sandwich bags',) ==> ('vegetables',) , 0.797
# Rule: ('waffles',) ==> ('vegetables',) , 0.800
# Rule: ('aluminum foil',) ==> ('vegetables',) , 0.808
# Rule: ('laundry detergent',) ==> ('vegetables',) , 0.817
# Rule: ('sugar',) ==> ('vegetables',) , 0.825
# Rule: ('yogurt',) ==> ('vegetables',) , 0.831
# Rule: ('eggs',) ==> ('vegetables',) , 0.838

# %% [markdown]
# # References
#
# [01] https://www.kaggle.com/acostasg/random-shopping-cart
#
# [02] https://github.com/asaini/Apriori

# %% [markdown]
# # Rubric
# * [02 points] - Student Details
# * [08 points] - Comply with submission instructions
# * [30 points] - DataSet Preprocess
# * [30 points] - Run apriory.py
# * [30 points] - Evaluate Results
